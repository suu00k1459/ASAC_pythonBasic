# %% [markdown]
# ## Dart 페이지 크롤링하기

# %%
# 필요한 패키지들
# 1) 통신 : urllib, requests

import requests

#2) html -> tag 중심의 언어
    # html의 테그를 중심으로 정보 추출 : BeautifulSoup
from bs4 import BeautifulSoup

#3) 데이터 처리
import pandas as pd

#4) + 정규식처리, 속도제어(지연 처리)
import re
import time
from datetime import datetime

# %%
# step1 ) 내가 요청하고자 하는 URL을 완성해야 함!
# -> API는 문서보고 하면 되는데
# -> 일반 사이트는 내가 열심히 필요한 정보를 요청하는 URL 탐색

# %%
# 예시 날짜 : 2024.03.05
# -> 698건의 공시 정보를 요청하려고 함.
# -> 1페이지가 아니라 여러 페이지를 롤링해야 함.

date= "2024.03.05" #<-selectDate=
page = "1" #<-currentPage

url = f"https://dart.fss.or.kr/dsac001/mainAll.do?selectDate={date}&sort=&series=&mdayCnt=0&currentPage={page}"
url
# Out:
# 'https://dart.fss.or.kr/dsac001/mainAll.do?selectDate=2024.03.05&sort=&series=&mdayCnt=0&currentPage=1'

# %%
#step2 ) requests 패키지로 요청
# -> 어제는 FM 적으로 params를 dict 로 만들어서 요청
# -> 이번에는 urlopen처럼 full url 직접 던질 때
res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
# 참고) request 패키지로 받은 정보를 열어보는 방식 2가지
# 1) res.text : 알아서 자기가 인코딩/ 디코딩을 처리를 함
#             특별하게 신경쓸 부분이 거의 없음!
# 2) res.content: 이미지, 동영상 --> 바이트값으로 들어옴.
# -> 일반적으로 특수한(이미지, 동영상), text를 주로 활용

# %%
res.text
# Out:
# '<!DOCTYPE html>\r\n\r\n\r\n\r\n\n\n\n\n\n\n\n\r\n<html xmlns="http://www.w3.org/1999/xhtml" xml:lang="ko" lang="ko">\r\n\t<head>\r\n\t\t<title>최근공시</title>\r\n\t\t<meta charset="UTF-8">\r\n\t\t<meta id="Viewport" name="viewport" content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0,user-scalable=yes">\r\n\t\t<meta http-equiv="X-UA-Compatible" content="ie=edge">\r\n\t\t\r\n\r\n\r\n\t\r\n<script type="text/javascript" src="/resource/js/jquery-3.3.1.min.js"></script>\r\n\r\n<link rel="stylesheet" href="/js/jquery-ui/jquery-ui.min.css">\r\n<script type="text/javascript" src="/js/jquery-ui/jquery-ui.min.js"></script>\r\n\r\n<!-- 2011.11.01 ext 2.3 -->\r\n<!--[if lte IE 8]><link rel="stylesheet" type="text/css" href="/js/ext-main/resources/css/ext-all-ie8.css" /><![endif]-->\r\n<script type="text/javascript" src="/js/ext-main/adapter/ext/ext-base.js"></script>\r\n<script type="text/javascript" src="/js/ext-main/ext-all.js"></script>\r\n\r\n<!-- x-xeries js libraries  -->\r\n<script type="text/javascript" src="/js/xjs.js?ver=1.18"></script>\r\n\r\n<!-- application js libraries -->\r\n<script type="text/javascript" src="/js/jsval.js" ></script>\r\n\r\n<!-- 웹표준 추가 스크립트-->\r\n<script type="text/javascript" src="/js/jquery/gotop.js"></script>\r\n\r\n<!-- 웹표준화적용사항 위반으로 DSAB001L.jsp에서 헤드로 위치 이동 -->\r\n<style type="text/css">\r\n.checked-icon {background-image: url(/images/temp/add.gif);}\r\n.ui-autocomplete {max-height: 100px; overflow-y: auto; overflow-x: hidden;}\r\n.ui-menu-item .ui-menu-item-wrapper.ui-state-active {background: #eaeaea !important; border: none; color:#333;}\r\n</style>\r\n<!--end -->\r\n\r\n<!-- 추가 되는 js, css 시작 -->\r\n<link rel="stylesheet" href="/resource/css/bootstrap.min.css">\r\n<link rel="stylesheet" href="/resource/css/slick.css">\r\n<link rel="stylesheet" href="/js/jsTree/default/style.css" />\r\n<link rel="stylesheet" href="/resource/css/bootstrap-datepicker3.css">\r\n<script type="text/javascript" src="/resource/js/bootstrap.bundle.min.js"></script>\r\n<script type="text/javascript" src="/resource/js/slick.min.js"></script>\r\n<script type="text/javascript" src="/js/jsTree/jstree.js"></script>\r\n<script type="text/javascript" src="/js/bootstrap-datepicker.js"></script>\r\n<script type="text/javascript" src="/js/bootstrap-datepicker.kr.min.js"></script>\r\n<script type="text/javascript" src="/js/idart/idart.js"></script><!-- idart용 -->\r\n<!-- 추가 되는 js, css 끝 -->\r\n\r\n<script type="text/javascript">\r\nfunction loadHistoryContents() {\r\n\txajax.initParameter();\r\n\txajax.blockUI = false;\r\n\txajax.simpleSend("/dsaf001/history.ax", function(html) {\r\n\t\t$j("#wingWrap").html(html);\r\n\t});\r\n}\r\n\r\n</script>\r\n<script type="text/javascript">\r\n(\r\n\tfunction(){\r\n\t\tvar s=function(){\r\n\t\t\t\t__flash__removeCallback=function(i,n){if(i)i[n]=null;\r\n\t\t\t};window.setTimeout(s,10);\r\n\t\t};s();\r\n\t}\r\n)();\r\n</script>\r\n\r\n<script type="text/javascript">\r\nfunction otherGongsi(){\r\n\tvar f_select = document.getElementById("f_select");\r\n\tvar link = f_select.options[f_select.selectedIndex].value;\r\n\tif(link != "f_slt_1"){\r\n\t\twindow.open(link);\r\n\t}\r\n\tif(link == "f_slt_1"){\r\n\t\talert("해외전자공시를 선택해주세요");\r\n\t}\r\n}\r\n</script>\r\n\t\t\r\n\r\n\t\r\n<link id="commonCss" rel="stylesheet" href="/css/common.css?ver=1.30" />\r\n<link id="userCssWeb" rel="stylesheet" href="/css/web.css?ver=1.175" />\r\n<link id="userCssTab" rel="stylesheet" href="/css/tablet.css?ver=5" />\r\n<link id="userCssMob" rel="stylesheet" href="/css/mobile.css?ver=1.170" />\r\n\r\n<script type="text/javascript" src="/js/common.js?ver=1.138"></script>\r\n\t\t<script type="text/javascript">\r\n\t\t//localStorage\r\n\t\t/* 향후 다크모드 적용발전을 위한 테스트\r\n\t\tdarkModeToggle(\'init\');\r\n\t\tfunction darkModeToggle(type){\r\n\t\t\tvar mode = localStorage.getItem(\'dartMode\');\r\n\t\t\t\r\n\t\t\tif(!(type && type == \'init\')){\r\n\t\t\t\tif(mode && mode == \'on\'){\r\n\t\t\t\t\t//현재 dar ...

# %%
# 위의 요청한 웹사이트의 내용을 필요한 정보에 쉽게 
# tag 중심으로 접근하기 위해서는 beautifulSoup 패키지로 변환!
# -> 정규식으로 모든 텍스트로 필요한 정보를 접근하는 게 아니라
#     tag 중심으로 정보 접근!

soup = BeautifulSoup(res.text, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko" xml:lang="ko" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <title>최근공시</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0,user-scalable=yes" id="Viewport" name="viewport"/>
# <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
# <script src="/resource/js/jquery-3.3.1.min.js" type="text/javascript"></script>
# <link href="/js/jquery-ui/jquery-ui.min.css" rel="stylesheet"/>
# <script src="/js/jquery-ui/jquery-ui.min.js" type="text/javascript"></script>
# <!-- 2011.11.01 ext 2.3 -->
# <!--[if lte IE 8]><link rel="stylesheet" type="text/css" href="/js/ext-main/resources/css/ext-all-ie8.css" /><![endif]-->
# <script src="/js/ext-main/adapter/ext/ext-base.js" type="text/javascript"></script>
# <script src="/js/ext-main/ext-all.js" type="text/javascript"></script>
# <!-- x-xeries js libraries  -->
# <script src="/js/xjs.js?ver=1.18" type="text/javascript"></script>
# <!-- application js libraries -->
# <script src="/js/jsval.js" type="text/javascript"></script>
# <!-- 웹표준 추가 스크립트-->
# <script src="/js/jquery/gotop.js" type="text/javascript"></script>
# <!-- 웹표준화적용사항 위반으로 DSAB001L.jsp에서 헤드로 위치 이동 -->
# <style type="text/css">
# .checked-icon {background-image: url(/images/temp/add.gif);}
# .ui-autocomplete {max-height: 100px; overflow-y: auto; overflow-x: hidden;}
# .ui-menu-item .ui-menu-item-wrapper.ui-state-active {background: #eaeaea !important; border: none; color:#333;}
# </style>
# <!--end -->
# <!-- 추가 되는 js, css 시작 -->
# <link href="/resource/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="/resource/css/slick.css" rel="stylesheet"/>
# <link href="/js/jsTree/default/style.css" rel="stylesheet">
# <link href="/resource/css/bootstrap-datepicker3.css" rel="stylesheet"/>
# <script src="/resource/js/bootstrap.bundle.min.js" type="text/javascript"></script>
# <script src="/resource/js/slick.min.js" type="text/javascript"></script>
# <script src="/js/jsTree/jstree.js" type="text/javascript"></script>
# <script src="/js/bootstrap-datepicker.js" type="text/javascript"></script>
# <script src="/js/bootstrap-datepicker.kr.min.js" type="text/javascript"></script>
# <script src="/js/idart/idart.js" type="text/javascript"></script><!-- idart용 -->
# <!-- 추가 되는 js, css 끝 -->
# <script type="text/javascript">
# function loadHistoryContents() {
# 	xajax.initParameter();
# 	xajax.blockUI = false;
# 	xajax.simpleSend("/dsaf001/history.ax", function(html) {
# 		$j("#wingWrap").html(html);
# 	});
# }
#
# </script>
# <script type="text/javascript">
# (
# 	function(){
# 		var s=function(){
# 				__flash__removeCallback=function(i,n){if(i)i[n]=null;
# 			};window.setTimeout(s,10);
# 		};s();
# 	}
# )();
# </script>
# <script type="text/javascript">
# function otherGongsi(){
# 	var f_select = document.getElementById("f_select");
# 	var link = f_select.options[f_select.selectedIndex].value;
# 	if(link != "f_slt_1"){
# 		window.open(link);
# 	}
# 	if(link == "f_slt_1"){
# 		alert("해외전자공시를 선택해주세요");
# 	}
# }
# </script>
# <link href="/css/common.css?ver=1.30" id="commonCss" rel="stylesheet">
# <link href="/css/web.css?ver=1.175" id="userCssWeb" rel="stylesheet">
# <link href="/css/tablet.css?ver=5" id="userCssTab" rel="stylesheet">
# <link href="/css/mobile.css?ver=1.170" id="userCssMob" rel="stylesheet"/>
# <script src="/js/common.js?ver=1.138" type="text/javascript"></script>
# <script type="text/javascript">
# 		//localStorage
# 		/* 향후 다크모드 적용발전을 위한 테스트
# 		darkModeToggle('init');
# 		function darkModeToggle(type){
# 			var mode = localStorage.getItem('dartMode');
#
# 			if(!(type && type == 'init')){
# 				if(mode && mode == 'on'){
# 					//현재 dark 모드
# 					localStorage.setItem('dartMode','off');
# 				}else{
# 					//현재 dark 모드
# 					localStorage.setItem('dartMode','on');
# 				}
#
# 				mode = localStorage.getItem('dartMode');
# 			}
#
# 			if(mode && mode == 'on'){
# 				$j('html').addClass('theme-dark');
# 			}else{
# 				$j('html').removeClass('theme-dark');
# 			}
# 		}
# 		*/
#
# 		var word = fn_getLocalStorage('defaultSearchWord');
# 		var val  = fn_getLocalStorage('defaultSearchValue');
#
# 		$j(document).ready(function() {
#
# 			if(word && val){
# 				var optionVal = val.replace(/\"/gi,'');
#
# 				if(optionVal=="corp"){
# 					getRef("headOption").innerHTML = "<option value='''>전체</option><option value='corp' selected>회사명</option><option value='report'>보고서명</option><option value='reportList'>보고서 목차명</option><option value='contents'>본문내용</option><option value='high'>고급검색</option>";
# 				}else if(optionVal=="report"){
# 					getRef("headOption").innerHTML = "<option value='''>전체</option><option value='corp'>회사명</option><option value='report' selected>보고서명</option><option value='reportList'>보고서 목차명</option><option value='contents'>본문내용</option><option value='high'>고급검색</option>";
# 				}else if(optionVal=="reportList"){
# 					getRef("headOption").innerHTML = "<option value='''>전체</option><option value='corp'>회사명</option><option value='report'>보고서명</option><option value='reportList' selected>보고서 목차명</option><option value='contents'>본문내용</option><option value='high'>고급검색</option>";
# 				}else if(optionVal=="contents"){
# 					getRef("headOption").innerHTML = "<option value='''>전체</option><option value='corp'>회사명</option><option value='report'>보고서명</option><option value='reportList'>보고서 목차명</option><option value='contents' selected>본문내용</option><option value='high'>고급검색</option>";
# 				}else if(optionVal=="contents"){
# 					getRef("headOption").innerHTML = "<option value='''>전체</option><option value='corp'>회사명</option><option value='report'>보고서명</option><option value='reportList'>보고서 목차명</option><option value='contents'>본문내용</option><option value='high' selected>고급검색</option>";
# 				}else{
# 					getRef("headOption").innerHTML = "<option value=''' selected>전체</option><option value='corp'>회사명</option><option value='report'>보고서명</option><option value='reportList'>보고서 목차명</option><option value='contents'>본문내용</option><option value='high'>고급검색</option>";
# 				}
#
# 			}else{
# 				getRef("headOption").innerHTML = "<option value='''>전체</option><option value='corp' selected>회사명</option><option value='report'>보고서명</option><option value='reportList'>보고서 목차명</option><option value='contents'>본문내용</option><option value='high'>고급검색</option>";
# 			}
#
# 			fn_headOptionChange();
# 			fn_scrollWingWrapSub();
# 		});
# 		/* wingWrap */
# 		function fn_scrollWingWrapSub(){
# 			$j(window).scroll(function(){
# 				var scrollTop = $j(document).scrollTop()+266;
# 				if(scrollTop < 266){
# 					scrollTop = 266;
# 				}
# 				$j('#wingWrap').stop();
# 				$j('#wingWrap').animate({'top':scrollTop});
# 			});
# 		}
# 	</script>
# </link></link></link></link></head>
# <body>
# <!-- 본문 바로가기 -->
# <!-- skipMenu -->
# <div class="loadingMask" id="loadingMask" style="display:none"></div>
# <div class="loadingWrap" id="loadingWrap" style="display:none">
# <div class="loadingImg"></div>
# <div class="loadingMessage">잠시만 기다려주세요.</div>
# </div>
# <div class="skipMenu"><a href="#contents">본문 바로가기</a></div>
# <div class="wrapper subPageBg">
# <script type="text/javascript">
# function openReportViewerEng(rcpNo, dcmNo){
# 	var url = "/dsbh001/main.do?rcpNo=" + rcpNo;
# 	if (dcmNo) {
# 		//<![CDATA[
# 		url += "&dcmNo=" + dcmNo;
# 		//]]>
# 	}
#
# 	var size = getOpenSize(1024, 768);
# 	window.open(url, rcpNo, size+",resizable=yes");
# 	$j("#r_"+rcpNo).css("color","#cd0093");
# }
#
# var win_num = 1;
# function openReportViewer(rcpNo, dcmNo){
# 	var url = "/dsaf001/main.do?rcpNo=" + rcpNo;
# 	if (dcmNo) {
# 		//<![CDATA[
# 		url += "&dcmNo=" + dcmNo;
# 		//]]>
# 	}
#
# 	var size = getOpenSize(1200, 810);
# 	window.open(url, rcpNo+win_num, size+",resizable=yes");
# 	win_num++;
# 	if (dcmNo) {
# 		$j("#r_"+rcpNo+dcmNo).css("color","#cd0093");
# 	}else{
# 		$j("#r_"+rcpNo).css("color","#cd0093");
# 	}
# }
#
# function openReportViewerParam(rcpNo, dcmNo, params){
# 	var url = "/dsaf001/main.do?rcpNo=" + rcpNo;
# 	if (dcmNo) {
# 		//<![CDATA[
# 		url += "&dcmNo=" + dcmNo;
# 		//]]>
# 	}
# 	if (params) {
# 		//<![CDATA[
# 		url += params;
# 		//]]>
# 	}
#
# 	var size = getOpenSize(1200, 810);
# 	window.open(url, rcpNo+win_num, size+",resizable=yes");
# 	win_num++;
# 	if (dcmNo) {
# 		$j("#r_"+rcpNo+dcmNo).css("color","#cd0093");
# 	}else{
# 		$j("#r_"+rcpNo).css("color","#cd0093");
# 	}
# }
#
# function openReportListViewer(rcpNo, dcmNo, eleId){
#
# 	var url = "/dsaf001/main.do?rcpNo=" + rcpNo;
# 	if (dcmNo) {
# 		//<![CDATA[
# 		url += "&dcmNo=" + dcmNo;
# 		//]]>
# 		if(eleId) {
# 			url += "&eleId=" + eleId;
# 		}
# 	}
#
# 	var size = getOpenSize(1200, 810);
# 	window.open(url, rcpNo+win_num, size+",resizable=yes");
# 	win_num++;
# 	if (dcmNo) {
# 		$j("#r_"+rcpNo+dcmNo).css("color","#cd0093");
# 	}else{
# 		$j("#r_"+rcpNo).css("color","#cd0093");
# 	}
# }
#
# /*
#  * 통합검색용 문서뷰어 팝업 호출
#  * nrseo 2010. 10. 20
#  * 2016.09.30 jsp에 직접 명시 하여 미사용(DSAB007A.jsp)
#  * - a:visited 미작동으로 인한 조치
#  */
# function openReportViewerKeyword(rcpNo, dcmNo, keyword){
# 	var url = "/dsaf001/main.do?rcpNo=" + rcpNo;
# 	if (dcmNo) {
# 		//<![CDATA[
# 		url += "&dcmNo=" + dcmNo;
# 		//]]>
# 	}
# 	//<![CDATA[
# 	url += "&keyword=" + encodeURIComponent(keyword);
# 	//]]>
#
# 	var size = getOpenSize(1024, 768);
# 	window.open(url, rcpNo+win_num, size+",resizable=yes");
# 	win_num++;
# 	if (dcmNo) {
# 		$j("#r_"+rcpNo+dcmNo).css("color","#cd0093");
# 	}else{
# 		$j("#r_"+rcpNo).css("color","#cd0093");
# 	}
# }
#
# /*
#  * 메인화면 전용
#  */
# function openReportViewerMain(rcpNo, dcmNo){
# 	var url = "/dsaf001/main.do?rcpNo=" + rcpNo;
# 	if (dcmNo) {
# 		//<![CDATA[
# 		url += "&dcmNo=" + dcmNo;
# 		//]]>
# 	}
#
# 	var size = getOpenSize(1200, 810);
# 	window.open(url, rcpNo+win_num, size+",resizable=yes");
# 	win_num++;
# }
#
# /*
#  * 사용(xbrl 미리보기)
#  */
# function openXbrlViewer(rcpNo, dcmNo, lang){
# 	var url = "";
# 	if (lang == "en") url = "https://englishdart.fss.or.kr/dsbh002/main.do?rcpNo=" + rcpNo;
# 	else url = "/dsaf002/main.do?rcpNo=" + rcpNo;
#
# 	if (dcmNo) {
# 		//<![CDATA[
# 		url += "&dcmNo=" + dcmNo;
# 		//]]>
# 	}
#
# 	var size = getOpenSize(1200, 810);
# 	window.open(url, rcpNo+win_num, size+",resizable=yes");
# 	win_num++;
# }
#
# /*
#  * 사용(xbrl뷰어 열기 팝업(opendart link))
#  */
# function openXbrlViewerNew(opendartUrl, rcpNo, stat, preview) {
# 	if (stat == "Y") {
# 		var url = opendartUrl + "/xbrl/viewer/main.do?rcpNo=" + rcpNo;
#
# 		var size = getOpenSize(1200, 810);
# 		window.open( url, rcpNo+win_num, size+",resizable=yes" );
# 		win_num++;
# 	} else if (stat == "N") {
# 		if (preview == "Y") {
# 			openXbrlViewer(rcpNo, "", "");
# 		} else {
# 			alert( '문서 생성중 입니다.\n잠시 후 다시 조회 하시기 바랍니다.' );
# 		}
# 	} else {
# 		alert( '생성된 문서가 없습니다.' );
# 	}
# }
#
# function openHelp(menu) {
# 	var url = "/guide/main.jsp";
# 	if (menu) {
# 		url += "?menu=" + menu;
# 	}
# 	var size = getOpenSize(1100, 761);
# 	var win = window.open(url, "DartGuide", size + ",resizable=yes,scrollbars=no");
# 	if (win == null) {
# 		alert("팝업차단을 해제하시기 바랍니다.");
# 	} else {
# 		win.focus();
# 	}
# }
#
# </script>
# <form action="/dsaf001/main.do" method="post" name="reportForm">
# <input name="rcpNo" type="hidden"/>
# <input name="dcmNo" type="hidden"/>
# <input name="keyword" type="hidden"/>
# <input style="display:none;" type="submit"/>
# </form>
# <!-- TOP LAYOUT START -->
# <div class="headerWrap">
# <div class="header">
# <!--  jsp:include flush="true"	page="/WEB-INF/jsp/include/includeTopLink.jsp" />-->
# <button class="btnMenu" title="메뉴 열기 버튼"></button>
# <div class="headerTop">
# <h1 class="logo" title="DART시스템 "><a href="/main.do">홈으로 가기</a></h1>
# </div>
# <div class="headerBottom">
# <div class="utilMenu">
# <form id="headSearchForm" method="post" name="headSearchForm" onsubmit="return false">
# <input name="autoSearch" type="hidden" value="Y"/>
# <input id="headSelDate" name="selDate" type="hidden" value="4"/>
# <input id="headStartDate" name="startDate" type="hidden" value=""/>
# <input id="headEndDate" name="endDate" type="hidden" value=""/>
# <input id="headLateKeyword" name="lateKeyword" type="hidden" value="0"/>
# <div class="topSearchWrap dpfl">
# <span class="frmSelect mgR5">
# <label for="headOption">선택</label>
# <select id="headOption" name="option" onchange="fn_headOptionChange();" title="목록선택">
# </select>
# </span>
# <span class="topSearch dpfl">
# <input class="dpno" id="headKeyword" name="keyword" onkeypress="if(event.keyCode==13){headSearch(1); return false;}" placeholder="검색어 입력" title="검색어 입력" type="text"/><label for="headKeyword">선택</label>
# <input class="dpno" id="headTextCrpNm" name="textCrpNm" onkeypress="if(event.keyCode==13){headSearch(1); return false;}" placeholder="회사명/종목코드 입력" style="display:none" title="회사명/종목코드 입력" type="text"/><label for="headTextCrpNm">선택</label>
# <input class="dpno" id="headReportName" name="reportName" onkeypress="if(event.keyCode==13){headSearch(1); return false;}" placeholder="보고서명 입력" style="display:none" title="보고서명 입력" type="text"/><label for="headReportName">선택</label>
# <input class="dpno" id="headTocSrch" name="tocSrch" onkeypress="if(event.keyCode==13){headSearch(1); return false;}" placeholder="보고서목차명 입력" style="display:none" title="보고서목차명 입력" type="text"/><label for="headTocSrch">선택</label>
# <input class="w01" id="headSearchWord" name="searchWord" onkeypress="if(event.keyCode==13){headSearch(1); return false;}" placeholder="회사명 보고서명 입력" style="display:none" title="회사명 보고서명 입력" type="text"/><label for="headSearchWord">선택</label>
# <input id="headContentWord" name="contentWord" onkeypress="if(event.keyCode==13){headSearch(1); return false;}" placeholder="본문내용 입력" style="display:none" title="본문내용 입력" type="text"/><label for="headContentWord">선택</label>
# <button onclick="headSearch()">검색</button>
# </span>
# </div>
# <div class="languageChoice">
# <ul>
# <li><a href="https://englishdart.fss.or.kr" target="_blank">ENGLISH</a></li>
# </ul>
# </div>
# </form>
# </div>
# <div class="gnb">
# <ul>
# <li id="menu_1">
# <a data-click="/dsac001/mainY.do" href="javascript:void(0);">최근공시</a>
# <ul>
# <li><a href="javascript:void(0);" onclick="goMenu('/dsac001/mainY.do', '');">유가증권시장</a></li>
# <li><a href="javascript:void(0);" onclick="goMenu('/dsac001/mainK.do', '');">코스닥시장</a></li>
# <li><a href="javascript:void(0);" onclick="goMenu('/dsac001/mainN.do', '');">코넥스시장</a></li>
# <li><a href="javascript:void(0);" onclick="goMenu('/dsac001/mainG.do', '');">기타법인</a></li>
# <li><a href="javascript:void(0);" onclick="goMenu('/dsac001/mainAll.do', '');">전체</a></li>
# <li><a href="javascript:void(0);" onclick="goMenu('/dsac001/mainO.do', '');">5%ㆍ임원보고</a></li>
# <li><a href="javascript:void(0);" onclick="goMenu('/dsac001/mainF.do', '');">펀드공시</a></li>
# <li><a href="javascript:void(0);" onclick="goMenu('/dsac001/mainMy.do', '');">My공시</a></li>
# </ul>
# </li>
# <li id="menu_2">
# <a data-click="/dsab007/main.do?option=corp" href="javascript:void(0);">공시서류검색</a>
# <ul>
# <li><a href="javascript:void(0);" onclick="goMenu('/dsab007/main.do?option=corp', '');">공시통합검색</a></li>
# <li><a href="javascript:void(0);" onclick="goMenu('/dsab001/main.do', '');">회사별검색</a></li>
# <li><a href="javascript:void(0);" onclick="goMenu('/dsab005/main.do', '');">펀드공시상세검색</a></li>
# <li><a href="javascript:void(0);" onclick="goMenu('/dsac003/mainY.do', '');">최근정정보고서</a></li>
# <li><a href="javascript:void(0);" onclick="goMenu('/dsac004/main.do', '');">최근삭제보고서</a></li>
# <li><a href="javascript:void(0);" onclick="goMenu('/dsab009/main.do', '');">고급검색</a></li>
# </ul>
# </li>
# <li id="menu_3">
# <a data-click="/dsae001/main.do" href="javascript:void(0);">기업개황</a>
# <ul>
# <li><a href="javascript:void(0);" onclick="goMenu('/dsae001/main.do', '');">기업개황</a></li>
# </ul>
# </li>
# <li id="menu_4">
# <a data-click="/dsac005/main.do" href="javascript:void(0);">공모정보</a>
# <ul>
# <li><a href="javascript:void(0);" onclick="goMenu('/dsac005/main.do', '');">공모게시판</a></li>
# <li><a href="javascript:void(0);" onclick="goMenu('/dsac006/main.do', '');">발행공시 검색</a></li>
# <li><a href="javascript:void(0);" onclick="goMenu('/dsac007/main.do', '');">모집ㆍ매출 실적</a></li>
# <li><a href="javascript:void(0);" onclick="goMenu('/dsac008/main.do', '');">청약달력(지분증권)</a></li>
# </ul>
# </li>
# <li>
# <a data-click="https://opendart.fss.or.kr/disclosureinfo/biz/main.do" data-gubun="open" href="javascript:void(0);">OpenDART</a>
# <ul>
# <li><a href="https://opendart.fss.or.kr/disclosureinfo/biz/main.do" target="_blank">공시정보활용마당<i class="outsideLink">외부링크</i></a></li>
# <li><a href="https://opendart.fss.or.kr/intro/infoApiList.do" target="_blank">오픈API<i class="outsideLink">외부링크</i></a></li>
# </ul>
# </li>
# <li><a data-click="/info/main.do" data-gubun="open" href="javascript:void(0);">공시업무ㆍ제도</a>
# <ul>
# <li><a href="/info/main.do" target="_blank">기업공시길라잡이<i class="outsideLink">외부링크</i></a></li>
# <li><a href="/info/searchGuide.do" target="_blank">기업공시제도일반<i class="outsideLink">외부링크</i></a></li>
# <li><a href="/info/searchBodo.do" target="_blank">보도자료<i class="outsideLink">외부링크</i></a></li>
# <li><a href="/info/main.do?menu=410" target="_blank">정기보고서 제출기한<i class="outsideLink">외부링크</i></a></li>
# </ul>
# </li>
# <li><a data-click="/introduction/content1.do" href="javascript:void(0);">DART 소개</a>
# <ul class="last">
# <li><a href="javascript:void(0);" onclick="goMenu('/introduction/content1.do', '');">전자공시시스템이란</a></li>
# <li><a href="javascript:void(0);" onclick="goMenu('/introduction/content2.do', '');">보고서정보</a></li>
# <li><a href="javascript:void(0);" onclick="goMenu('/introduction/content3.do', '');">관계법규 등</a></li>
# <li><a href="javascript:void(0);" onclick="goMenu('/introduction/content4.do', '');">정정신고서이용시 유의사항</a></li>
# <li><a href="javascript:void(0);" onclick="goMenu('/dsah004/main.do', '');">DART알림마당</a></li>
# <li><a href="javascript:void(0);" onclick="goMenu('/introduction/content5.do', '');">정보이용시 유의사항</a></li>
# <li><a href="javascript:void(0);" onclick="goMenu('/introduction/content6.do', '');">RSS</a></li>
# </ul>
# </li>
# </ul>
# </div>
# <button class="btnMenuAll" onclick="location.href='/sitemap.do'" title="전체메뉴가기">전체메뉴보기</button>
# <button class="btnMenuClose" title="메뉴 닫기 버튼"></button>
# <div class="subBg"></div>
# <div class="mask"></div>
# </div>
# </div>
# </div>
# <!-- TOP LAYOUT END -->
# <!-- BODY LALYOUT START -->
# <div id="container">
# <div id="contentsWrap">
# <!-- LEFT LALYOUT START -->
# <script type="text/javascript">
#
# function menuOn(obj, url) {
# 	/*자바스크립트를 제거 하더라도 이동이 가능하도록 a태그 안에 실제 URL맵핑함 2012/06/12 유영근*/
# 	$j("#lnbWrap").find(".on").removeClass();
# 	$j(obj).parent().addClass("on");
# 	moveMenuAc001(url);
#
# }
#
# function moveMenuAc001(url) {
# 	/*자바스크립트를 제거 하더라도 이동이 가능하도록 a태그 안에 실제 URL맵핑함 2012/06/12 유영근*/
# 	var amp = "&";
# 	document.location.replace(url + "?selectDate=" + $j("#selectDate").val() + amp +"sort=" + $j("#sort").val() + amp+"series=" + $j("#series").val() +amp +"mdayCnt=" +$j("#mdayCnt").val());
# 	//url에  & -> &amp; 적용시 타브라우저에서 기능 정상작동이 안됨.
# }
#
# </script>
# <div id="lnbWrap">
# <div id="lnb">
# <h2>최근공시</h2>
# <ul>
# <li id="dsac001_mainY">
# <a href="#none" onclick="menuOn(this, '/dsac001/mainY.do');">유가증권시장</a>
# </li>
# <li id="dsac001_mainK">
# <a href="#none" onclick="menuOn(this, '/dsac001/mainK.do');">코스닥시장</a>
# </li>
# <li id="dsac001_mainN">
# <a href="#none" onclick="menuOn(this, '/dsac001/mainN.do');">코넥스시장</a>
# </li>
# <li id="dsac001_mainG">
# <a href="#none" onclick="menuOn(this, '/dsac001/mainG.do');">기타법인</a>
# </li>
# <li id="dsac001_mainAll">
# <a href="#none" onclick="menuOn(this, '/dsac001/mainAll.do');">전체</a>
# </li>
# <li id="dsac001_mainO">
# <a href="#none" onclick="menuOn(this, '/dsac001/mainO.do');">5%ㆍ임원보고</a>
# </li>
# <li id="dsac001_mainF">
# <a href="#none" onclick="menuOn(this, '/dsac001/mainF.do');">펀드공시</a> <!-- on은 select off에는  -->
# </li>
# <li id="dsac001_mainMy">
# <a href="#none" onclick="menuOn(this, '/dsac001/mainMy.do');">My 공시</a>
# </li>
# </ul>
# </div>
# </div>
# <!-- LEFT LAYOUT END -->
# <!-- MAIN LALYOUT START -->
# <div id="contents">
# <script>
# 	$j(document).ready(function() {
#
#
# 		var uri = "/dsac001/mainAll.do";
#
# 		var menuPath = uri.split("/");
# 		var tempPath;
# 		if(menuPath.length == 3){
# 			tempPath = menuPath[2].split('.');
# 			menuPath[2] = tempPath[0]
# 		}
#
# 		var menuData =
# 		{
# 			"dsac001":{
# 				"mainY":{
# 					"subTitle":"유가증권시장",
# 					"path":["home" ,"최근공시", "유가증권시장"]
# 				},
# 				"mainK":{
# 					"subTitle":"코스닥시장",
# 					"path":["home" ,"최근공시", "코스닥시장"]
# 				},
# 				"mainN":{
# 					"subTitle":"코넥스시장",
# 					"path":["home" ,"최근공시", "코넥스시장"]
# 				},
# 				"mainG":{
# 					"subTitle":"기타법인",
# 					"path":["home" ,"최근공시", "기타법인"]
# 				},
# 				"mainAll":{
# 					"subTitle":"전체",
# 					"path":["home" ,"최근공시", "전체"]
# 				},
# 				"mainO":{
# 					"subTitle":"5%ㆍ임원보고",
# 					"path":["home" ,"최근공시", "5%ㆍ임원보고"]
# 				},
# 				"mainF":{
# 					"subTitle":"펀드공시",
# 					"path":["home" ,"최근공시", "펀드공시"]
# 				},
# 				"mainMy":{
# 					"subTitle":"My 공시",
# 					"path":["home" ,"최근공시", "My 공시"]
# 				},
# 			},  "dsac003":{
# 				"mainY":{
# 					"subTitle":"최근정정보고서",
# 					"path":["home" ,"공시서류검색", "최근정정보고서"]
# 				}
# 			}, "dsac004":{
# 				"main":{
# 					"subTitle":"최근삭제보고서",
# 					"path":["home" ,"공시서류검색", "최근삭제보고서"]
# 				}
# 			}, "dsab009":{
# 				"main":{
# 					"subTitle":"고급검색",
# 					"path":["home" ,"공시서류검색", "고급검색"]
# 				}
# 			}, "dsac005":{
# 				"main":{
# 					"subTitle":"공모게시판",
# 					"path":["home" ,"공모정보", "공모게시판"]
# 				}
# 			}, "dsac006":{
# 				"main":{
# 					"subTitle":"발행공시 검색",
# 					"path":["home" ,"공모정보", "발행공시 검색"]
# 				}
# 			}, "dsac007":{
# 				"main":{
# 					"subTitle":"모집ㆍ매출 실적",
# 					"path":["home" ,"공모정보", "모집ㆍ매출 실적"]
# 				}
# 			}, "dsac008":{
# 				"main":{
# 					"subTitle":"청약 달력(지분증권)",
# 					"path":["home" ,"공모정보", "청약 달력(지분증권)"]
# 				}
# 			}, "dsab005":{
# 				"main":{
# 					"subTitle":"펀드공시상세검색",
# 					"path":["home" ,"공시서류검색", "펀드공시상세검색"]
# 				}
# 			}, "dsah004":{
# 				"main":{
# 					"subTitle":"DART알림마당",
# 					"path":["home" ,"공시업무ㆍ제도", "DART알림마당"]
# 				},
# 				"select":{
# 					"subTitle":"DART알림마당",
# 					"path":["home" ,"공시업무ㆍ제도", "DART알림마당"]
# 				}
# 			}, "dsab007":{
# 				"main":{
# 					"subTitle":"공시통합검색",
# 					"path":["home" ,"공시서류검색", "공시통합검색"]
# 				}
# 			}, "dsab001": {
# 				"main":{
# 					"subTitle":"회사별 검색",
# 					"path":["home" ,"공시서류검색", "회사별검색"]
# 				}
# 			}, "dsae001":{
# 				"main":{
# 					"subTitle":"기업개황",
# 					"path":["home" ,"기업개황",""]
# 				}
# 			}, "introduction":{
# 				"content1":{
# 					"subTitle":"전자공시시스템이란",
# 					"path":["home" ,"DART 소개","전자공시시스템이란"]
# 				},
# 				"content2":{
# 					"subTitle":"보고서정보",
# 					"path":["home" ,"DART 소개","보고서정보"]
# 				},
# 				"content3":{
# 					"subTitle":"관계법규 등",
# 					"path":["home" ,"DART 소개","관계법규 등"]
# 				},
# 				"content4":{
# 					"subTitle":"정정신고서이용시 유의사항",
# 					"path":["home" ,"DART 소개","정정신고서이용시 유의사항"]
# 				},
# 				"content5":{
# 					"subTitle":"정보이용시 유의사항",
# 					"path":["home" ,"DART 소개","정보이용시 유의사항"]
# 				},
# 				"content6":{
# 					"subTitle":"RSS",
# 					"path":["home" ,"DART 소개","RSS"]
# 				}
# 			}, "sitemap":{
# 				"sitemap":{
# 					"subTitle":"사이트 맵",
# 					"path":["home" ,"사이트 맵",""]
# 				}
# 			}
# 		}
#
# 		if(menuPath.length == 3){
# 			var menu = menuData[menuPath[1]][menuPath[2]]
# 			$j("#subTitle").text(menu.subTitle);
#
# 			var pathHTML = "";
# 			var path = menu["path"];
# 			path.forEach(function(data,key){
# 				pathHTML += "<li>" + data + "</li>";
# 			});
# 			$j("#path").html(pathHTML);
#
# 			//상세화면 조건분리
# 			if(menuPath[1] == 'dsah004' || menuPath[2] == 'select'){
# 				menuPath[2] = 'main';
# 			}
# 			//menu on
# 			$j("#"+menuPath[1] + '_' + menuPath[2]).addClass("on");
# 		}
# 		//상세화면 조건분리
# 		if(menuPath[1] == 'sitemap.do'){
# 			menuPath[1] = 'sitemap';
# 			menuPath[2] = 'sitemap';
# 			var menu = menuData[menuPath[1]][menuPath[2]]
# 			$j("#subTitle").text(menu.subTitle);
#
# 			var pathHTML = "";
# 			var path = menu["path"];
# 			path.forEach(function(data,key){
# 				pathHTML += "<li>" + data + "</li>";
# 			});
# 			$j("#path").html(pathHTML);
# 		}
# 	});
# </script>
# <div class="headTitle">
# <h3 id="subTitle"></h3>
# <ul class="navy" id="path">
# </ul>
# </div>
# <script type="text/javascript">
# 	var calSelectDate;
# 	$j(document).ready(function() {
# 		initLayerNew('winCorpInfo');
#
# 		$j("#calDate").datepicker({
# 			language : "kr",
# 			format : "yyyy.mm.dd",
# 			startDate: new Date(1999, 1-1, 1)
# 		}).datepicker('setDate', new Date()).on("changeDate", function(selected){
# 			var year = selected.date.getFullYear();
# 			if(year <1999) {
# 				alert("날짜가 올바르지 않습니다.");
# 				$j("#calDate").datepicker('setDate', new Date());
# 				return;
# 			}
# 			var month = (selected.date.getMonth()+1) >= 10?(selected.date.getMonth()+1):'0'+ (selected.date.getMonth()+1);
# 			var day = selected.date.getDate()>= 10?selected.date.getDate():'0' + selected.date.getDate();
# 			var selectedDate = year + '.' + month+'.'+day;
# 			$j(".datepicker").hide();
# 			$j("#selectDate").val(selectedDate);
# 			$j("#mdayCnt").val("0");
# 			moveMenuAc001("");
# 			selected.stopPropagation();
# 		});
#
# 		// window 타이틀 세팅
# 		var wTtitle="";
# 		var rss = document.getElementById('rss');
# 		switch(""){
# 		case "Y":
# 			wTtitle = "유가증권시장";
# 			rss.style.visibility="visible";
# 			break;
# 		case "K":
# 			wTtitle = "코스닥시장";
# 			rss.style.visibility="visible";
# 			break;
# 		case "N":
# 			wTtitle = "코넥스시장";
# 			rss.style.visibility="visible";
# 			break;
# 		case "G":
# 			wTtitle = "기타법인";
# 			rss.style.visibility="visible";
# 			break;
# 		case "O":
# 			wTtitle = "5%ㆍ임원보고";
# 			rss.style.visibility="hidden";
# 			break;
# 		case "F":
# 			wTtitle = "펀드공시";
# 			rss.style.visibility="hidden";
# 			break;
# 		case "":
# 			wTtitle = "전체";
# 			rss.style.visibility = "visible";
# 			break;
# 		default:
# 			wTtitle = "유가증권시장";
# 			rss.style.visibility="visible";
# 			break;
# 		}
#
# 		window.document.title ="전자공시시스템 | 최근공시 | " + wTtitle;
# 		$j(".table_list tr:nth-child(even)").addClass("even");
# 	});
#
# 	/**
# 	 * 검색단
# 	 */
# 	function search(page) {
# 		var frm = findForm("searchForm");
# 		if(page=='') page=1;
# 	    frm.currentPage.value = page;
# 	    xajax.blockUI = false;
# 		xajax.blockTarget = "listContents";
# 		window.scrollTo(0,0);
# 	    xajax.sendForm("searchForm", "/dsac001/search.ax", function(str) {
# 	    	getRef("listContents").innerHTML = str;
# 	    	$j(".table_list tr:nth-child(even)").addClass("even");
# 	    	var totalCnt = comma($j("#totalCnt").val());
# 	    	$j('#txtCB').text(totalCnt);
# 	    });
# 	}
#
# 	function comma(num) {
# 		return num.toString().replace(/\B(?=(\d{3})+(?!\d))/g, ",");
# 	}
# 	function searchDate(){
# 		xajax.sendForm("searchForm", "/dsac001/searchDate.ax", function(str) {
# 			getRef("date").innerHTML = str;
# 			$j(".table_list tr:nth-child(even)").addClass("even");
# 		});
# 	}
#
# 	/**
# 	 * 날짜탭버튼 변경
# 	 */
# 	function changeMdayCnt(obj, v){
# 		findForm("searchForm").mdayCnt.value = v;
# 		$j(".dateChoice").find(".on").removeClass();
# 		$j(obj).attr("class", "on");
# 		search('1');
# 	}
#
#
# 	function pageGroupChg(key){
# 		var frm = findForm("searchForm");
# 		frm.pageGrouping.value = key;
# 		frm.submit();
# 	}
#
#
# 	function selectDate2() {
# 		//xcalendar.showWindow(calSelectDate);
# 	}
#
#
# 	function setAutoCompletionText(text) {
# 		getRef("searchForm").textCrpNm.value = text;
# 		clearAutoCompletion();
# 	}
#
#
#
# 	/**
# 	 * 엑셀다운로드
# 	 */
# 	function downloadExcel(){
#
# 		// 회사명을 지운다.
# 		clearSearchCorpText();
# 		xajax.queryString="";
# 		xajax.addParameterForm("searchForm");
# 		var quertyString = xajax.queryString;
# 		xajax.queryString="";
# 		var url = "/dsac001/ExcelDownload.do?"+quertyString;
# 		location.href = url;
# 	}
#
# 	function setOrder(obj){
# 		var series=document.searchForm.series;
# 		var sort=document.searchForm.sort;
#
# 		var names=$j("a[name='sort']");
# 		for(var i=0;i<names.length;i++){
# 			if(names[i].id==obj.id){
# 				var order = $j(names[i]).data('order');
# 				sort.value=obj.id;
# 				if(order=="asc"){
# 					series.value="desc";
# 					$j(names[i]).data('order', 'desc');
# 				} else{
# 					series.value="asc";
# 					$j(names[i]).data('order', 'asc');
# 				}
# 			}
# 		}
# 		search('');
# 	}
#
# </script>
# <!-- helpWrap -->
# <div class="helpWrap">
# <a class="btn" href="javascript:void(0);" id="rss" onclick="scrapFeed('today'); return false;" style="visibility: hidden;" title="RSS주소복사"><i class="iconRss"></i>RSS주소복사</a>
# <a class="btn" href="javascript:void(0);" onclick="openHelp(110); return false;" title="도움말"><i class="iconHelp"></i>도움말</a>
# </div>
# <form action="/dsac001/mainY.do" id="searchForm" method="post" name="searchForm">
# <input id="currentPage" name="currentPage" type="hidden" value=""/>
# <input id="maxResults" name="maxResults" type="hidden" value=""/>
# <input id="maxLinks" name="maxLinks" type="hidden" value=""/>
# <input id="sort" name="sort" type="hidden" value=""/>
# <input id="series" name="series" type="hidden" value=""/>
# <input id="pageGrouping" name="pageGrouping" type="hidden" value=""/>
# <input id="mdayCnt" name="mdayCnt" type="hidden" value="0"/>
# <input id="selectDate" name="selectDate" type="hidden" value="2024.03.05"/>
# <input id="textCrpCik" name="textCrpCik" type="hidden" value=""/>
# <input name="goAction" style="display:none" type="submit"/>
# <!--날짜선택-->
# <div class="dateChoice">
# <div class="dateWrap">
# <a class="on" href="#date" onclick="changeMdayCnt(this, '0'); return false;" style="cursor:pointer" title="03월 05일">
# 						03월 05일
# 					</a>
# <a href="#date" onclick="changeMdayCnt(this, '1'); return false;" style="cursor:pointer" title="03월 04일">
# 						03월 04일
# 					</a>
# <a href="#date" onclick="changeMdayCnt(this, '5'); return false;" style="cursor:pointer" title="02월 29일">
# 						02월 29일
# 					</a>
# </div>
# <div class="dateWrap">
# <a href="#date" onclick="changeMdayCnt(this, '6'); return false;" style="cursor:pointer" title="02월 28일">
# 						02월 28일
# 					</a>
# <a href="#date" onclick="changeMdayCnt(this, '7'); return false;" style="cursor:pointer" title="02월 27일">
# 						02월 27일
# 					</a>
# <a class="calDate" href="javascript:void(0);" id="calDate" title="날짜선택">날짜선택</a>
# </div>
# </div>
# </form>
# <div class="tbListWrap" id="listContents">
# <!--목록 -->
# <div class="tbTitle">
# <h4>
#
#
#
#
#
#
#
# 			전체
#
# 		 <span class="txtCB" id="txtCB">698</span>건
#
#
#
#
# 					(2024년 03월 05일)
#
#
#
#
#
#
#
#
#
#
#
# 	</h4>
# <div class="sort">
# <a class="downOn" data-order="desc" href="#none" id="time" name="sort" onclick="setOrder(this);" title="시간 내림차순">시간</a>
# <a class="upOff" data-order="asc" href="#none" id="crp" name="sort" onclick="setOrder(this);" title="회사명 올림차순">회사명</a>
# <a class="upOff" data-order="asc" href="#none" id="rpt" name="sort" onclick="setOrder(this);" title="보고서명 올림차순">보고서명</a>
# </div>
# </div>
# <div class="tbListInner">
# <table class="tbList" summary="시간,공시대상회사,보고서명,제출인,접수일자,비고 순으로 되어있습니다.">
# <caption>유가증권시장 목록</caption>
# <colgroup>
# <col style="width:7%"/>
# <col style="width:24%"/>
# <col style="width:auto"/>
# <col style="width:13%"/>
# <col style="width:11%"/>
# <col style="width:8%"/>
# </colgroup>
# <thead>
# <tr>
# <th scope="row"><label for="inpSample00">시간</label></th>
# <th scope="row"><label for="inpSample00">공시대상회사</label></th>
# <th scope="row"><label for="inpSample00">보고서명</label></th>
# <th scope="row"><label for="inpSample00">제출인</label></th>
# <th scope="row"><label for="inpSample00">접수일자</label></th>
# <th scope="row"><label for="inpSample00">비고</label></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>
#
#
#
# 								19:29
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('01375822', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="에이프릴바이오 기업개황 새창">
# 										에이프릴바이오
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305901186" id="r_20240305901186" onclick="openReportViewer('20240305901186'); return false;" title="매출액또는손익구조30%(대규모법인은15%)이상변동 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>매출액또는손익구조30%(대규모법인은15%)이상변동
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="에이프릴바이오">에이프릴바이오</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								18:58
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('00249441', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="씨씨에스 기업개황 새창">
# 										씨씨에스
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305000637" id="r_20240305000637" onclick="openReportViewer('20240305000637'); return false;" title="주요사항보고서(소송등의제기) 공시뷰어 새창">주요사항보고서(소송등의제기)
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="씨씨에스">씨씨에스</td>
# <td>2024.03.06</td>
# <td></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								18:50
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('00560849', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="에스앤디 기업개황 새창">
# 										에스앤디
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305901177" id="r_20240305901177" onclick="openReportViewer('20240305901177'); return false;" title="주주총회집중일개최사유신고 공시뷰어 새창">주주총회집중일개최사유신고
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="에스앤디">에스앤디</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								18:48
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('00681249', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="씨유메디칼 기업개황 새창">
# 										씨유메디칼
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305901172" id="r_20240305901172" onclick="openReportViewer('20240305901172'); return false;" title="주주총회소집결의 공시뷰어 새창">주주총회소집결의
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="씨유메디칼">씨유메디칼</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								18:43
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
# <a href="javascript:openCorpInfoNew('00107598', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="남양유업 기업개황 새창">
# 										남양유업
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305801171" id="r_20240305801171" onclick="openReportViewer('20240305801171'); return false;" title="소송등의제기ㆍ신청(경영권분쟁소송) 공시뷰어 새창">소송등의제기ㆍ신청(경영권분쟁소송)
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="남양유업">남양유업</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_kospi_other" style="cursor:default" title="본 공시사항은 한국거래소 유가증권시장본부 소관임">유</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								18:43
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('00249441', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="씨씨에스 기업개황 새창">
# 										씨씨에스
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305901175" id="r_20240305901175" onclick="openReportViewer('20240305901175'); return false;" title="소송등의제기ㆍ신청(경영권분쟁소송)(이사회결의 효력정지 및 대표이사직무집행정지 가처분) 공시뷰어 새창">소송등의제기ㆍ신청(경영권분쟁소송)
#
# 		  							(이사회결의 효력정지 및 대표이사직무집행정지 가처분)
# 								</a>
# </td>
# <td class="tL ellipsis" title="씨씨에스">씨씨에스</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span><span class="tagCom_jung_other" style="cursor:default" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								18:42
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
# <a href="javascript:openCorpInfoNew('00159810', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="카프로 기업개황 새창">
# 										카프로
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305801174" id="r_20240305801174" onclick="openReportViewer('20240305801174'); return false;" title="주주총회소집결의 공시뷰어 새창">주주총회소집결의
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="카프로">카프로</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_kospi_other" style="cursor:default" title="본 공시사항은 한국거래소 유가증권시장본부 소관임">유</span><span class="tagCom_jung_other" style="cursor:default" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								18:41
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
# <a href="javascript:openCorpInfoNew('00159810', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="카프로 기업개황 새창">
# 										카프로
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305000629" id="r_20240305000629" onclick="openReportViewer('20240305000629'); return false;" title="주요사항보고서(감자결정) 공시뷰어 새창">주요사항보고서(감자결정)
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="카프로">카프로</td>
# <td>2024.03.06</td>
# <td><span class="tagCom_jung_other" style="cursor:default" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								18:36
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('00296324', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="큐로홀딩스 기업개황 새창">
# 										큐로홀딩스
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305901165" id="r_20240305901165" onclick="openReportViewer('20240305901165'); return false;" title="최대주주변경을수반하는주식담보제공계약체결 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>최대주주변경을수반하는주식담보제공계약체결
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="큐로홀딩스">큐로홀딩스</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								18:30
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('00458562', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="에이티세미콘 기업개황 새창">
# 										에이티세미콘
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305901162" id="r_20240305901162" onclick="openReportViewer('20240305901162'); return false;" title="주권관련사채권의취득결정 공시뷰어 새창">주권관련사채권의취득결정
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="에이티세미콘">에이티세미콘</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								18:29
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('00458562', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="에이티세미콘 기업개황 새창">
# 										에이티세미콘
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305901161" id="r_20240305901161" onclick="openReportViewer('20240305901161'); return false;" title="기타경영사항(자율공시)(주식회사 에이티세미콘 제16회차 무기명식 이권부 무보증 사모 전환사채 취득 후 재매각의 건) 공시뷰어 새창">기타경영사항(자율공시)
#
# 		  							(주식회사 에이티세미콘 제16회차 무기명식 이권부 무보증 사모 전환사채 취득 후 재매각의 건)
# 								</a>
# </td>
# <td class="tL ellipsis" title="에이티세미콘">에이티세미콘</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								18:23
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('00257149', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="지더블유바이텍 기업개황 새창">
# 										지더블유바이텍
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305901159" id="r_20240305901159" onclick="openReportViewer('20240305901159'); return false;" title="최대주주변경 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>최대주주변경
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="지더블유바이텍">지더블유바이텍</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								18:21
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('00458562', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="에이티세미콘 기업개황 새창">
# 										에이티세미콘
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305901160" id="r_20240305901160" onclick="openReportViewer('20240305901160'); return false;" title="기타경영사항(자율공시)(제12회차, 제14회차, 제16회차 무기명식 이권부 무보증 사모 전환사채 취득 후 재매각의 건) 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>기타경영사항(자율공시)
#
# 		  							(제12회차, 제14회차, 제16회차 무기명식 이권부 무보증 사모 전환사채 취득 후 재매각의 건)
# 								</a>
# </td>
# <td class="tL ellipsis" title="에이티세미콘">에이티세미콘</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								18:21
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('00560849', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="에스앤디 기업개황 새창">
# 										에스앤디
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305901164" id="r_20240305901164" onclick="openReportViewer('20240305901164'); return false;" title="주주총회소집결의 공시뷰어 새창">주주총회소집결의
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="에스앤디">에스앤디</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								18:14
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('01182550', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="EDGC 기업개황 새창">
# 										EDGC
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305901157" id="r_20240305901157" onclick="openReportViewer('20240305901157'); return false;" title="주주총회소집결의 공시뷰어 새창">주주총회소집결의
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="EDGC">EDGC</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								18:11
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('00267942', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="큐캐피탈 기업개황 새창">
# 										큐캐피탈
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305901098" id="r_20240305901098" onclick="openReportViewer('20240305901098'); return false;" title="최대주주변경을수반하는주식담보제공계약체결 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>최대주주변경을수반하는주식담보제공계약체결
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="큐캐피탈">큐캐피탈</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								18:10
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('01689938', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="신영스팩9호 기업개황 새창">
# 										신영스팩9호
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305901124" id="r_20240305901124" onclick="openReportViewer('20240305901124'); return false;" title="감사보고서제출 공시뷰어 새창">감사보고서제출
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="신영스팩9호">신영스팩9호</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								18:09
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('00683007', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="엑스큐어 기업개황 새창">
# 										엑스큐어
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305901091" id="r_20240305901091" onclick="openReportViewer('20240305901091'); return false;" title="주주총회소집결의 공시뷰어 새창">주주총회소집결의
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="엑스큐어">엑스큐어</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								18:09
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('00919966', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="신라젠 기업개황 새창">
# 										신라젠
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305901089" id="r_20240305901089" onclick="openReportViewer('20240305901089'); return false;" title="주주총회집중일개최사유신고 공시뷰어 새창">주주총회집중일개최사유신고
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="신라젠">신라젠</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								18:09
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('01068658', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="디딤이앤에프 기업개황 새창">
# 										디딤이앤에프
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305901069" id="r_20240305901069" onclick="openReportViewer('20240305901069'); return false;" title="주주명부폐쇄기간또는기준일설정 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>주주명부폐쇄기간또는기준일설정
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="디딤이앤에프">디딤이앤에프</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span><span class="tagCom_jung_other" style="cursor:default" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								18:08
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('01068658', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="디딤이앤에프 기업개황 새창">
# 										디딤이앤에프
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305901064" id="r_20240305901064" onclick="openReportViewer('20240305901064'); return false;" title="주주총회소집결의(임시주주총회) 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>주주총회소집결의
#
# 		  							(임시주주총회)
# 								</a>
# </td>
# <td class="tL ellipsis" title="디딤이앤에프">디딤이앤에프</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								18:03
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('00470829', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="한솔인티큐브 기업개황 새창">
# 										한솔인티큐브
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305901058" id="r_20240305901058" onclick="openReportViewer('20240305901058'); return false;" title="주주총회소집결의 공시뷰어 새창">주주총회소집결의
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="한솔인티큐브">한솔인티큐브</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								18:03
# 							</td>
# <td class="tL">
# ...
# <td>2024.03.05</td>
# <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span><span class="tagCom_jung_other" style="cursor:default" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								17:36
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
# <a href="javascript:openCorpInfoNew('00244455', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="케이티앤지 기업개황 새창">
# 										케이티앤지
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305000580" id="r_20240305000580" onclick="openReportViewer('20240305000580'); return false;" title="의결권대리행사권유참고서류 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>의결권대리행사권유참고서류
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="케이티앤지">케이티앤지</td>
# <td>2024.03.05</td>
# <td></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								17:36
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('01046203', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="스튜디오산타클로스 기업개황 새창">
# 										스튜디오산타클로스
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305000574" id="r_20240305000574" onclick="openReportViewer('20240305000574'); return false;" title="주요사항보고서(주권관련사채권양수결정) 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>주요사항보고서(주권관련사채권양수결정)
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="스튜디오산타클로스">스튜디오산타클로스</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_jung_other" style="cursor:default" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								17:36
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('01046203', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="스튜디오산타클로스 기업개황 새창">
# 										스튜디오산타클로스
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305000561" id="r_20240305000561" onclick="openReportViewer('20240305000561'); return false;" title="주요사항보고서(유상증자결정) 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>주요사항보고서(유상증자결정)
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="스튜디오산타클로스">스튜디오산타클로스</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_jung_other" style="cursor:default" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								17:36
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('00307028', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="경남제약 기업개황 새창">
# 										경남제약
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305000579" id="r_20240305000579" onclick="openReportViewer('20240305000579'); return false;" title="의결권대리행사권유참고서류 공시뷰어 새창">의결권대리행사권유참고서류
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="경남제약">경남제약</td>
# <td>2024.03.05</td>
# <td></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								17:36
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('00409681', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="아스트 기업개황 새창">
# 										아스트
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305000533" id="r_20240305000533" onclick="openReportViewer('20240305000533'); return false;" title="주요사항보고서(유상증자결정) 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>주요사항보고서(유상증자결정)
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="아스트">아스트</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_jung_other" style="cursor:default" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								17:35
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
# <a href="javascript:openCorpInfoNew('00244455', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="케이티앤지 기업개황 새창">
# 										케이티앤지
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305000578" id="r_20240305000578" onclick="openReportViewer('20240305000578'); return false;" title="의결권대리행사권유참고서류 공시뷰어 새창">의결권대리행사권유참고서류
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="AGNES">AGNES</td>
# <td>2024.03.05</td>
# <td></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								17:35
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
# <a href="javascript:openCorpInfoNew('00165680', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="호텔신라 기업개황 새창">
# 										호텔신라
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305800986" id="r_20240305800986" onclick="openReportViewer('20240305800986'); return false;" title="감사보고서제출 공시뷰어 새창">감사보고서제출
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="호텔신라">호텔신라</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_kospi_other" style="cursor:default" title="본 공시사항은 한국거래소 유가증권시장본부 소관임">유</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								17:34
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('00815767', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="위메이드플레이 기업개황 새창">
# 										위메이드플레이
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305000577" id="r_20240305000577" onclick="openReportViewer('20240305000577'); return false;" title="주주총회소집공고 공시뷰어 새창">주주총회소집공고
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="위메이드플레이">위메이드플레이</td>
# <td>2024.03.05</td>
# <td></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								17:34
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('00161462', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="에이티넘인베스트 기업개황 새창">
# 										에이티넘인베스트
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305000576" id="r_20240305000576" onclick="openReportViewer('20240305000576'); return false;" title="주주총회소집공고 공시뷰어 새창">주주총회소집공고
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="에이티넘인베스트">에이티넘인베스트</td>
# <td>2024.03.05</td>
# <td></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								17:33
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('00560122', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="한울소재과학 기업개황 새창">
# 										한울소재과학
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305901016" id="r_20240305901016" onclick="openReportViewer('20240305901016'); return false;" title="거래처와의거래중단 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>거래처와의거래중단
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="한울소재과학">한울소재과학</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								17:33
# 							</td>
# <td class="tL">
# <span class="innerWrapTag">
# <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
# <a href="javascript:openCorpInfoNew('00111722', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="미래에셋증권 기업개황 새창">
# 										미래에셋증권
# 									</a>
# </span>
# <a href="http://ci.securities.miraeasset.com" target="new">
# <span class="tagCom_ir" title="기업 IR페이지 연결">IR</span>
# </a>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305000573" id="r_20240305000573" onclick="openReportViewer('20240305000573'); return false;" title="투자설명서(일괄신고) 공시뷰어 새창">투자설명서(일괄신고)
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="미래에셋증권">미래에셋증권</td>
# <td>2024.03.05</td>
# <td></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								17:32
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
# <a href="javascript:openCorpInfoNew('00113526', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="대한항공 기업개황 새창">
# 										대한항공
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305800959" id="r_20240305800959" onclick="openReportViewer('20240305800959'); return false;" title="감사보고서제출 공시뷰어 새창">감사보고서제출
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="대한항공">대한항공</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_kospi_other" style="cursor:default" title="본 공시사항은 한국거래소 유가증권시장본부 소관임">유</span></td>
# </tr>
# <tr>
# <td>
#
#
#
# 								17:31
# 							</td>
# <td class="tL">
# <span class="innerWrapTag">
# <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
# <a href="javascript:openCorpInfoNew('00111722', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="미래에셋증권 기업개황 새창">
# 										미래에셋증권
# 									</a>
# </span>
# <a href="http://ci.securities.miraeasset.com" target="new">
# <span class="tagCom_ir" title="기업 IR페이지 연결">IR</span>
# </a>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305000569" id="r_20240305000569" onclick="openReportViewer('20240305000569'); return false;" title="일괄신고추가서류(파생결합증권-주가연계증권) 공시뷰어 새창">일괄신고추가서류(파생결합증권-주가연계증권)
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="미래에셋증권">미래에셋증권</td>
# <td>2024.03.05</td>
# <td></td>
# </tr>
# </tbody>
# <input id="totalCnt" name="totalCnt" type="hidden" value="698"/>
# </table>
# </div>
# <div class="psWrap">
# <div class="pageInfo">[1/7] [총 698건]</div>
# <div class="pageSkip">
# <ul>
# <li class="on"><a onclick="javascript:void(0);">1</a></li><li><a href="javascript:search(2);">2</a></li><li><a href="javascript:search(3);">3</a></li><li><a href="javascript:search(4);">4</a></li><li><a href="javascript:search(5);">5</a></li><li><a href="javascript:search(6);">6</a></li><li><a href="javascript:search(7);">7</a></li>
# </ul>
# </div>
# </div>
# </div>
# <!--비고정보-->
# <div class="messageBoxBottom">
# <div class="messageBox">
# <ul>
# <i class="iconInfoO"></i>
# <li class="info">
# 				상기 보고서명 앞의 대괄호([]) 및 비고란의 약어(예:<span class="tagCom_jung_other" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span>)에 마우스를 위치하면 설명이 나타나니 참고하시기 바랍니다.
# 			</li>
# </ul>
# </div>
# </div>
# </div>
# <!-- MAIN LALYOUT END -->
# </div>
# <div class="wingWrap" id="wingWrap">
# <script type="text/javascript">
# $j(document).ready(function() {
# 	$j('.btnTop').click(function(){
# 		 $j(document).scrollTop(0);
# 	});
# 	if(onlyWebCssMode != null && onlyWebCssMode == "on"){
# 		$j('#onlyWebCssMode').prop('checked', true);
# 	}
# });
# function clickUpHistory() {
# 	var width = $j('#history').find('li').outerHeight(true);
# 	document.getElementById("history").scrollTop = document.getElementById("history").scrollTop - width;
# }
#
# function clickDownHistory() {
# 	var width = $j('#history').find('li').outerHeight(true);
# 	document.getElementById("history").scrollTop = document.getElementById("history").scrollTop + width;
# }
#
# </script>
# <script type="text/javascript">initMoving(document.getElementById("historyContents"), 180, 100, 250);</script>
# <span class="uiCheck">
# <label for="onlyWebCssMode">창크기변경시 UI고정</label>
# <input id="onlyWebCssMode" name="onlyWebCssMode" type="checkbox" value="on">
# </input></span>
# <div class="title">오늘본문서</div>
# <div class="wingBtn">
# <div>
# <!--데이타가 나올때-->
# <div class="psNumber">
# 			(총0건)
# 		</div>
# <div class="btnUp" onclick="clickUpHistory();">
# <a href="javascript:void(0);" onclick="clickUpHistory();" title="이전 문서">위로</a>
# </div>
# <ul id="history" style="overflow: hidden; ">
# </ul>
# <div class="btnDown" onclick="clickDownHistory();">
# <a href="javascript:void(0);" onclick="clickDownHistory();" title="다음 문서">아래로</a>
# </div>
# </div>
# </div>
# <div class="survey">
# <a class="btnSuvey" href="/dsah004/select.do?no=78&amp;gubun=N&amp;list_no=13" title="FAQ 바로가기"><span>홈페이지<br/>이용관련</span><span>FAQ</span></a>
# </div>
# <a class="btnGuide" href="javascript:void(0);" onclick="openHelp(100); return false;" title="이용가이드 바로가기">이용가이드</a>
# <a class="btnTop" href="javascript:void(0);">위로</a>
# </div>
# </div>
# </div>
# <!-- BOTTOM LAYOUT START -->
# <!-- <div id="layoutBottom"> -->
# <script type="text/javascript">
# 	function altChange(){
# 		var sIndex = document.getElementById("f_select").options.selectedIndex;
# 		document.getElementById("go_confirm").alt = document.getElementById("f_select").options[sIndex].text + " 이동";
# 		document.getElementById("go_confirm").title = document.getElementById("f_select").options[sIndex].text + " 이동";
# 	}
#
# 	function doPrsnInfoPolicy(){
# 		var size = getOpenSize(730, 750);
# 		var popWin = window.open('/jsp/popup/prsnInfoPolicy.jsp', 'PRSNINFOPOLICY', ''+size+', status=no, scrollbars=yes');
# 	   	popWin.focus();
# 	}
#
# 	function openBanner(ban_type){
# 		xajax.initParameter();
# 		xajax.addParameter("ban_type", ban_type);
# 		xajax.simpleSend("/banner/count.ax");
# 	}
# </script>
# <a class="btnClose" href="javascript:void(0);" onclick="fn_scrollTop();"><div class="mBtnTop">맨위로</div></a>
# <div id="footerBannerWrap">
# <div id="footerBanner">
# <div class="leftCont">
# <ul>
# <li><a href="https://www.fss.or.kr" target="_blank" title="새창열림"><img alt="금융감독원 바로가기" src="../images/footer_banner_01.png"/></a></li>
# <li><a href="http://www.fsc.go.kr/" target="_blank" title="새창열림"><img alt="금융위원회 바로가기" src="../images/footer_banner_02.png"/></a></li>
# <li><a href="http://www.ftc.go.kr/" target="_blank" title="새창열림"><img alt="공정거래위원회 바로가기" src="../images/footer_banner_03.png"/></a></li>
# </ul>
# </div>
# <div class="rightCont">
# <ul>
# <li><a href="https://www.fss.or.kr/fss/job/lrgInfoMain/intro.do?menuNo=200485" target="_blank" title="새창열림"><img alt="금융감독법규 바로가기" src="../images/footer_banner_04.png"/></a></li>
# <li><a href="https://www.fss.or.kr/fss/main/contents.do?menuNo=200289" target="_blank" title="새창열림"><img alt="불법금융신고센터 바로가기" src="../images/footer_banner_05.png"/></a></li>
# <li><a href="https://www.fss.or.kr/fss/main/contents.do?menuNo=200427" target="_blank" title="새창열림"><img alt="금융감독원 회계포탈 바로가기" src="../images/footer_banner_06.png"/></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div id="footerWrap">
# <div id="footer">
# <div class="logo"><img alt="풋터 로고" src="../images/footer_logo.png"/></div>
# <div class="fnbWrap">
# <div class="fnb">
# <ul>
# <li><a href="/jsp/privacy.jsp" target="_blank" title="개인정보처리방침 새창"><b>개인정보 처리방침</b></a></li>
# <li><a href="/introduction/content5.do">정보이용시 유의사항</a></li>
# <li><a href="/introduction/content2.do">보고서정보</a></li>
# <li><a href="/introduction/content6.do">RSS서비스</a></li>
# </ul>
# </div>
# <div class="copy">
# <p>서울특별시 영등포구 여의대로 38 대표전화 : 02) 3145-5114</p>
# <p>Copyright ㉿FINANCIAL SUPERVISORY SERVICE ALL Rights Reserved.</p>
# </div>
# </div>
# <div class="inquiry">
# <p>홈페이지 이용문의 : (국번없이)1332 (5번-&gt;1번-&gt;1번)</p>
# <p>기업공시 제도문의 : (국번없이)1332 (5번-&gt;1번-&gt;2,3,4,5번)</p>
# </div>
# <div class="footeMark"><img alt="ISO 20000 인증" src="../images/footer_mark.png" title="ISO 20000 인증"/></div>
# </div>
# </div>
# <!-- layer popup wrap -->
# <div id="winCommMsg" style="display:none">
# <div class="mask" style="display:block"></div>
# <!-- layer popup wrap -->
# </div>
# <!-- </div> -->
# <!-- BOTTOM LAYOUT END -->
# <script type="text/javascript">
# 			$j(document).ready(function() {
# 				if( navigator.userAgent.match(/Android|iPhone|iPad/) == null) {
# 					$j("#divMobileLink").css("display", "none");
# 				} else {
# 					$j("#divMobileLink").css("display", "block");
# 				}
# 			});
# 		</script>
# </body>
# </html>

# %%
# -> 웹 페이지의 내용을 파이썬으로 땡겨옴!
# 이제 나의 필요한 정보를 테그 중심으로 접근

# -> xml 은 단순 tag값만 알면 정보 찾는데 문제가 없는데, 
# -> html은 tag안에 많은 표현/ 출력에 관련도니 속성들이 존재
# 단순 tag 하나만으로는 접근하기 애매함 : tag + tag 의 속성들을 같이 활용해서 접근

# %%
# 방법 1) dict로 상세 속성을 지정하는 방식
len(soup.find_all("div"))
# Out:
# 58

# %%
soup.find_all("div")[0] #롤링해서 하나하나 찾는 건 비효율적!!!
# Out:
# <div class="loadingMask" id="loadingMask" style="display:none"></div>

# %%
soup.find_all("div", {"class":"headerTop"})
# Out:
# [<div class="headerTop">
#  <h1 class="logo" title="DART시스템 "><a href="/main.do">홈으로 가기</a></h1>
#  </div>]

# %%
# 방법2) tag 중에서 bs4 가 이미 파라미터로 만들어둔 것!
#     ex) class 파라미터의 경우에는 : class_
soup.find_all("div", class_ = "headerTop")
# Out:
# [<div class="headerTop">
#  <h1 class="logo" title="DART시스템 "><a href="/main.do">홈으로 가기</a></h1>
#  </div>]

# %%
# Q) 전체 그 날의 공시 자료 수 체크
#     -> 내가 몇 개의 페이지를 돌려야 할지(그냥 1페이지부터 쭉 돌리면서, 체크를 하는 방법도 있음)
#     -> 정규식 같은 것도 쓰고, 뭔가 규칙을 찾아보기 위함(수업적 내용)
#       테이블 아래 [1/7] [총 698건] 에서 찾아보도록 하겠음.  

temp = soup.find_all("div", {"class":"pageInfo"})[0].text
temp
# Out:
# '[1/7] [총 698건]'

# %%
# + 필요한 부분 정규식!
# -> 정규식에서 특정 문자 패턴을 찾는 것 : re.findall(패턴, 어디서)
# -> 정규식에서 특정 문자 패턴을 변경/ 제거 : re.sub(패턴, 무엇으로 변경, 어디서)

# %%
# try1 ) 찾을 패턴 : 숫자들 + 건
temp = re.findall(r"\d+건", temp)[0] # 698건
temp = re.sub(r"건","",temp)
temp
# Out:
# '698'

# %%
# 페이지 계산 : 1페이지 최대 100건
# 100으로 나눠서 몫을 올림

if int(temp) % 100 == 0:
    tot_page= int(temp) //100
else :
    tot_pate = int(temp) //100 + 1

# %%
# try2) 이번에는 정보에서 /???] --? ???페이지 정보추출

temp = soup.find_all("div", {"class","pageInfo"})[0].text
temp1 = re.findall(r"/\d+\]",temp)[0] # re.findall(r"[0-9]+",temp)
temp1 = re.sub(r"\/|\]","",temp1)
temp1
# Out:
# '7'

# %%
# 필요한 정보(공시관련)들을 추출해보자.
# Q) 1개 공시 정보에 대한 tr 테그를 찾아보자
soup.find_all("tr") # 테이블 head(1), body(100) = 101개
# Out:
# [<tr>
#  <th scope="row"><label for="inpSample00">시간</label></th>
#  <th scope="row"><label for="inpSample00">공시대상회사</label></th>
#  <th scope="row"><label for="inpSample00">보고서명</label></th>
#  <th scope="row"><label for="inpSample00">제출인</label></th>
#  <th scope="row"><label for="inpSample00">접수일자</label></th>
#  <th scope="row"><label for="inpSample00">비고</label></th>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								19:29
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('01375822', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="에이프릴바이오 기업개황 새창">
#  										에이프릴바이오
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901186" id="r_20240305901186" onclick="openReportViewer('20240305901186'); return false;" title="매출액또는손익구조30%(대규모법인은15%)이상변동 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>매출액또는손익구조30%(대규모법인은15%)이상변동
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="에이프릴바이오">에이프릴바이오</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								18:58
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00249441', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="씨씨에스 기업개황 새창">
#  										씨씨에스
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000637" id="r_20240305000637" onclick="openReportViewer('20240305000637'); return false;" title="주요사항보고서(소송등의제기) 공시뷰어 새창">주요사항보고서(소송등의제기)
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="씨씨에스">씨씨에스</td>
#  <td>2024.03.06</td>
#  <td></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								18:50
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00560849', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="에스앤디 기업개황 새창">
#  										에스앤디
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901177" id="r_20240305901177" onclick="openReportViewer('20240305901177'); return false;" title="주주총회집중일개최사유신고 공시뷰어 새창">주주총회집중일개최사유신고
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="에스앤디">에스앤디</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								18:48
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00681249', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="씨유메디칼 기업개황 새창">
#  										씨유메디칼
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901172" id="r_20240305901172" onclick="openReportViewer('20240305901172'); return false;" title="주주총회소집결의 공시뷰어 새창">주주총회소집결의
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="씨유메디칼">씨유메디칼</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								18:43
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('00107598', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="남양유업 기업개황 새창">
#  										남양유업
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305801171" id="r_20240305801171" onclick="openReportViewer('20240305801171'); return false;" title="소송등의제기ㆍ신청(경영권분쟁소송) 공시뷰어 새창">소송등의제기ㆍ신청(경영권분쟁소송)
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="남양유업">남양유업</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kospi_other" style="cursor:default" title="본 공시사항은 한국거래소 유가증권시장본부 소관임">유</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								18:43
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00249441', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="씨씨에스 기업개황 새창">
#  										씨씨에스
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901175" id="r_20240305901175" onclick="openReportViewer('20240305901175'); return false;" title="소송등의제기ㆍ신청(경영권분쟁소송)(이사회결의 효력정지 및 대표이사직무집행정지 가처분) 공시뷰어 새창">소송등의제기ㆍ신청(경영권분쟁소송)
#
#  		  							(이사회결의 효력정지 및 대표이사직무집행정지 가처분)
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="씨씨에스">씨씨에스</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span><span class="tagCom_jung_other" style="cursor:default" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								18:42
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('00159810', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="카프로 기업개황 새창">
#  										카프로
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305801174" id="r_20240305801174" onclick="openReportViewer('20240305801174'); return false;" title="주주총회소집결의 공시뷰어 새창">주주총회소집결의
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="카프로">카프로</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kospi_other" style="cursor:default" title="본 공시사항은 한국거래소 유가증권시장본부 소관임">유</span><span class="tagCom_jung_other" style="cursor:default" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								18:41
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('00159810', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="카프로 기업개황 새창">
#  										카프로
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000629" id="r_20240305000629" onclick="openReportViewer('20240305000629'); return false;" title="주요사항보고서(감자결정) 공시뷰어 새창">주요사항보고서(감자결정)
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="카프로">카프로</td>
#  <td>2024.03.06</td>
#  <td><span class="tagCom_jung_other" style="cursor:default" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								18:36
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00296324', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="큐로홀딩스 기업개황 새창">
#  										큐로홀딩스
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901165" id="r_20240305901165" onclick="openReportViewer('20240305901165'); return false;" title="최대주주변경을수반하는주식담보제공계약체결 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>최대주주변경을수반하는주식담보제공계약체결
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="큐로홀딩스">큐로홀딩스</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								18:30
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00458562', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="에이티세미콘 기업개황 새창">
#  										에이티세미콘
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901162" id="r_20240305901162" onclick="openReportViewer('20240305901162'); return false;" title="주권관련사채권의취득결정 공시뷰어 새창">주권관련사채권의취득결정
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="에이티세미콘">에이티세미콘</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								18:29
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00458562', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="에이티세미콘 기업개황 새창">
#  										에이티세미콘
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901161" id="r_20240305901161" onclick="openReportViewer('20240305901161'); return false;" title="기타경영사항(자율공시)(주식회사 에이티세미콘 제16회차 무기명식 이권부 무보증 사모 전환사채 취득 후 재매각의 건) 공시뷰어 새창">기타경영사항(자율공시)
#
#  		  							(주식회사 에이티세미콘 제16회차 무기명식 이권부 무보증 사모 전환사채 취득 후 재매각의 건)
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="에이티세미콘">에이티세미콘</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								18:23
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00257149', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="지더블유바이텍 기업개황 새창">
#  										지더블유바이텍
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901159" id="r_20240305901159" onclick="openReportViewer('20240305901159'); return false;" title="최대주주변경 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>최대주주변경
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="지더블유바이텍">지더블유바이텍</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								18:21
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00458562', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="에이티세미콘 기업개황 새창">
#  										에이티세미콘
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901160" id="r_20240305901160" onclick="openReportViewer('20240305901160'); return false;" title="기타경영사항(자율공시)(제12회차, 제14회차, 제16회차 무기명식 이권부 무보증 사모 전환사채 취득 후 재매각의 건) 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>기타경영사항(자율공시)
#
#  		  							(제12회차, 제14회차, 제16회차 무기명식 이권부 무보증 사모 전환사채 취득 후 재매각의 건)
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="에이티세미콘">에이티세미콘</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								18:21
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00560849', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="에스앤디 기업개황 새창">
#  										에스앤디
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901164" id="r_20240305901164" onclick="openReportViewer('20240305901164'); return false;" title="주주총회소집결의 공시뷰어 새창">주주총회소집결의
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="에스앤디">에스앤디</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								18:14
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('01182550', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="EDGC 기업개황 새창">
#  										EDGC
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901157" id="r_20240305901157" onclick="openReportViewer('20240305901157'); return false;" title="주주총회소집결의 공시뷰어 새창">주주총회소집결의
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="EDGC">EDGC</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								18:11
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00267942', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="큐캐피탈 기업개황 새창">
#  										큐캐피탈
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901098" id="r_20240305901098" onclick="openReportViewer('20240305901098'); return false;" title="최대주주변경을수반하는주식담보제공계약체결 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>최대주주변경을수반하는주식담보제공계약체결
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="큐캐피탈">큐캐피탈</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								18:10
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('01689938', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="신영스팩9호 기업개황 새창">
#  										신영스팩9호
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901124" id="r_20240305901124" onclick="openReportViewer('20240305901124'); return false;" title="감사보고서제출 공시뷰어 새창">감사보고서제출
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="신영스팩9호">신영스팩9호</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								18:09
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00683007', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="엑스큐어 기업개황 새창">
#  										엑스큐어
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901091" id="r_20240305901091" onclick="openReportViewer('20240305901091'); return false;" title="주주총회소집결의 공시뷰어 새창">주주총회소집결의
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="엑스큐어">엑스큐어</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								18:09
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00919966', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="신라젠 기업개황 새창">
#  										신라젠
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901089" id="r_20240305901089" onclick="openReportViewer('20240305901089'); return false;" title="주주총회집중일개최사유신고 공시뷰어 새창">주주총회집중일개최사유신고
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="신라젠">신라젠</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								18:09
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('01068658', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="디딤이앤에프 기업개황 새창">
#  										디딤이앤에프
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901069" id="r_20240305901069" onclick="openReportViewer('20240305901069'); return false;" title="주주명부폐쇄기간또는기준일설정 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>주주명부폐쇄기간또는기준일설정
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="디딤이앤에프">디딤이앤에프</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span><span class="tagCom_jung_other" style="cursor:default" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								18:08
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('01068658', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="디딤이앤에프 기업개황 새창">
#  										디딤이앤에프
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901064" id="r_20240305901064" onclick="openReportViewer('20240305901064'); return false;" title="주주총회소집결의(임시주주총회) 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>주주총회소집결의
#
#  		  							(임시주주총회)
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="디딤이앤에프">디딤이앤에프</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								18:03
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00470829', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="한솔인티큐브 기업개황 새창">
#  										한솔인티큐브
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901058" id="r_20240305901058" onclick="openReportViewer('20240305901058'); return false;" title="주주총회소집결의 공시뷰어 새창">주주총회소집결의
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="한솔인티큐브">한솔인티큐브</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								18:03
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('00148896', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="OCI홀딩스 기업개황 새창">
#  										OCI홀딩스
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305801129" id="r_20240305801129" onclick="openReportViewer('20240305801129'); return false;" title="감사보고서제출 공시뷰어 새창">감사보고서제출(자회사의 주요경영사항)
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="OCI홀딩스">OCI홀딩스</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kospi_other" style="cursor:default" title="본 공시사항은 한국거래소 유가증권시장본부 소관임">유</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								18:01
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('01656374', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="신영스팩8호 기업개황 새창">
#  										신영스팩8호
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901116" id="r_20240305901116" onclick="openReportViewer('20240305901116'); return false;" title="감사보고서제출 공시뷰어 새창">감사보고서제출
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="신영스팩8호">신영스팩8호</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:59
#  							</td>
#  <td class="tL">
#  <span class="innerWrapTag">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('00120571', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="롯데칠성음료 기업개황 새창">
#  										롯데칠성음료
#  									</a>
#  </span>
#  <a href="https://company.lottechilsung.co.kr/kor/invest/irreport/list.do" target="new">
#  <span class="tagCom_ir" title="기업 IR페이지 연결">IR</span>
#  </a>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000621" id="r_20240305000621" onclick="openReportViewer('20240305000621'); return false;" title="의결권대리행사권유참고서류 공시뷰어 새창">의결권대리행사권유참고서류
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="롯데칠성음료">롯데칠성음료</td>
#  <td>2024.03.05</td>
#  <td></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:59
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('00404701', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="한국자산신탁 기업개황 새창">
#  										한국자산신탁
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000620" id="r_20240305000620" onclick="openReportViewer('20240305000620'); return false;" title="주주총회소집공고 공시뷰어 새창">주주총회소집공고
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="한국자산신탁">한국자산신탁</td>
#  <td>2024.03.05</td>
#  <td></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:59
#  							</td>
#  <td class="tL">
#  <span class="innerWrapTag">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('01201970', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="클리노믹스 기업개황 새창">
#  										클리노믹스
#  									</a>
#  </span>
#  <a href="http://www.clinomics.com/" target="new">
#  <span class="tagCom_ir" title="기업 IR페이지 연결">IR</span>
#  </a>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000608" id="r_20240305000608" onclick="openReportViewer('20240305000608'); return false;" title="주요사항보고서(유상증자결정) 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>주요사항보고서(유상증자결정)
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="클리노믹스">클리노믹스</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_jung_other" style="cursor:default" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:59
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('01612608', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="신영스팩7호 기업개황 새창">
#  										신영스팩7호
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901111" id="r_20240305901111" onclick="openReportViewer('20240305901111'); return false;" title="감사보고서제출 공시뷰어 새창">감사보고서제출
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="신영스팩7호">신영스팩7호</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:58
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('01760738', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="OCI 기업개황 새창">
#  										OCI
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305801114" id="r_20240305801114" onclick="openReportViewer('20240305801114'); return false;" title="감사보고서제출 공시뷰어 새창">감사보고서제출
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="OCI">OCI</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kospi_other" style="cursor:default" title="본 공시사항은 한국거래소 유가증권시장본부 소관임">유</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:58
#  							</td>
#  <td class="tL">
#  <span class="innerWrapTag">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00223762', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="지니뮤직 기업개황 새창">
#  										지니뮤직
#  									</a>
#  </span>
#  <a href="https://www.geniemusic.co.kr/main/index.do" target="new">
#  <span class="tagCom_ir" title="기업 IR페이지 연결">IR</span>
#  </a>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901095" id="r_20240305901095" onclick="openReportViewer('20240305901095'); return false;" title="감사보고서제출 공시뷰어 새창">감사보고서제출
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="지니뮤직">지니뮤직</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:58
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('01524093', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="DL이앤씨 기업개황 새창">
#  										DL이앤씨
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305801127" id="r_20240305801127" onclick="openReportViewer('20240305801127'); return false;" title="최대주주등소유주식변동신고서 공시뷰어 새창">최대주주등소유주식변동신고서
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="DL이앤씨">DL이앤씨</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kospi_other" style="cursor:default" title="본 공시사항은 한국거래소 유가증권시장본부 소관임">유</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:58
#  							</td>
#  <td class="tL">
#  <span class="innerWrapTag">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('00120021', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="LG 기업개황 새창">
#  										LG
#  									</a>
#  </span>
#  <a href="http://www.lg.co.kr" target="new">
#  <span class="tagCom_ir" title="기업 IR페이지 연결">IR</span>
#  </a>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305801113" id="r_20240305801113" onclick="openReportViewer('20240305801113'); return false;" title="감사보고서제출 공시뷰어 새창">감사보고서제출(자회사의 주요경영사항)
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="LG">LG</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kospi_other" style="cursor:default" title="본 공시사항은 한국거래소 유가증권시장본부 소관임">유</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:55
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('00118345', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="디아이동일 기업개황 새창">
#  										디아이동일
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305801122" id="r_20240305801122" onclick="openReportViewer('20240305801122'); return false;" title="소송등의제기ㆍ신청(경영권분쟁소송) 공시뷰어 새창">소송등의제기ㆍ신청(경영권분쟁소송)
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="디아이동일">디아이동일</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kospi_other" style="cursor:default" title="본 공시사항은 한국거래소 유가증권시장본부 소관임">유</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:55
#  							</td>
#  <td class="tL">
#  <span class="innerWrapTag">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('00120571', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="롯데칠성음료 기업개황 새창">
#  										롯데칠성음료
#  									</a>
#  </span>
#  <a href="https://company.lottechilsung.co.kr/kor/invest/irreport/list.do" target="new">
#  <span class="tagCom_ir" title="기업 IR페이지 연결">IR</span>
#  </a>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000615" id="r_20240305000615" onclick="openReportViewer('20240305000615'); return false;" title="주주총회소집공고 공시뷰어 새창">주주총회소집공고
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="롯데칠성음료">롯데칠성음료</td>
#  <td>2024.03.05</td>
#  <td></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:54
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00317487', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="티에스넥스젠 기업개황 새창">
#  										티에스넥스젠
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000614" id="r_20240305000614" onclick="openReportViewer('20240305000614'); return false;" title="주요사항보고서(자기전환사채매도결정) 공시뷰어 새창">주요사항보고서(자기전환사채매도결정)
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="티에스넥스젠">티에스넥스젠</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_jung_other" style="cursor:default" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:54
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('01070149', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="올리패스 기업개황 새창">
#  										올리패스
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000597" id="r_20240305000597" onclick="openReportViewer('20240305000597'); return false;" title="주요사항보고서(유상증자결정) 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>주요사항보고서(유상증자결정)
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="올리패스">올리패스</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_jung_other" style="cursor:default" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:54
#  							</td>
#  <td class="tL">
#  <span class="innerWrapTag">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('00120571', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="롯데칠성음료 기업개황 새창">
#  										롯데칠성음료
#  									</a>
#  </span>
#  <a href="https://company.lottechilsung.co.kr/kor/invest/irreport/list.do" target="new">
#  <span class="tagCom_ir" title="기업 IR페이지 연결">IR</span>
#  </a>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305801106" id="r_20240305801106" onclick="openReportViewer('20240305801106'); return false;" title="주주총회소집결의 공시뷰어 새창">주주총회소집결의
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="롯데칠성음료">롯데칠성음료</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kospi_other" style="cursor:default" title="본 공시사항은 한국거래소 유가증권시장본부 소관임">유</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:53
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('00539274', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="대상홀딩스 기업개황 새창">
#  										대상홀딩스
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305801013" id="r_20240305801013" onclick="openReportViewer('20240305801013'); return false;" title="주주총회소집결의 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>주주총회소집결의
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="대상홀딩스">대상홀딩스</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kospi_other" style="cursor:default" title="본 공시사항은 한국거래소 유가증권시장본부 소관임">유</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:53
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_konex" style="cursor:default" title="코넥스시장">넥</span>
#  <a href="javascript:openCorpInfoNew('00578325', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="럭스피아 기업개황 새창">
#  										럭스피아
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000610" id="r_20240305000610" onclick="openReportViewer('20240305000610'); return false;" title="주주총회소집공고 공시뷰어 새창">주주총회소집공고
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="럭스피아">럭스피아</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_jung_other" style="cursor:default" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:52
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_etc" style="cursor:default" title="기타법인">기</span>
#  <a href="javascript:openCorpInfoNew('01213832', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="스노우 기업개황 새창">
#  										스노우
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000609" id="r_20240305000609" onclick="openReportViewer('20240305000609'); return false;" title="비유동자산처분결정 공시뷰어 새창">비유동자산처분결정
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="스노우">스노우</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_gong_other" style="cursor:default" title="본 공시사항은 공정거래위원회 소관임">공</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:52
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00230036', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="드래곤플라이 기업개황 새창">
#  										드래곤플라이
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901048" id="r_20240305901048" onclick="openReportViewer('20240305901048'); return false;" title="주주총회집중일개최사유신고 공시뷰어 새창">주주총회집중일개최사유신고
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="드래곤플라이">드래곤플라이</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:52
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00230036', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="드래곤플라이 기업개황 새창">
#  										드래곤플라이
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901042" id="r_20240305901042" onclick="openReportViewer('20240305901042'); return false;" title="주주총회소집결의 공시뷰어 새창">주주총회소집결의
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="드래곤플라이">드래곤플라이</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span><span class="tagCom_jung_other" style="cursor:default" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:51
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('00231363', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="LG유플러스 기업개황 새창">
#  										LG유플러스
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305801033" id="r_20240305801033" onclick="openReportViewer('20240305801033'); return false;" title="감사보고서제출 공시뷰어 새창">감사보고서제출
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="LG유플러스">LG유플러스</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kospi_other" style="cursor:default" title="본 공시사항은 한국거래소 유가증권시장본부 소관임">유</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:51
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('01316254', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="효성첨단소재 기업개황 새창">
#  										효성첨단소재
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305801105" id="r_20240305801105" onclick="openReportViewer('20240305801105'); return false;" title="풍문또는보도에대한해명(미확정) 공시뷰어 새창">풍문또는보도에대한해명(미확정)
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="효성첨단소재">효성첨단소재</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kospi_other" style="cursor:default" title="본 공시사항은 한국거래소 유가증권시장본부 소관임">유</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:50
#  							</td>
#  <td class="tL">
#  <span class="innerWrapTag">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00367695', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="DGP 기업개황 새창">
#  										DGP
#  									</a>
#  </span>
#  <a href="http://www.daehangreenpower.com" target="new">
#  <span class="tagCom_ir" title="기업 IR페이지 연결">IR</span>
#  </a>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000607" id="r_20240305000607" onclick="openReportViewer('20240305000607'); return false;" title="의결권대리행사권유참고서류 공시뷰어 새창">의결권대리행사권유참고서류
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="김인수">김인수</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_jung_other" style="cursor:default" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:50
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00230036', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="드래곤플라이 기업개황 새창">
#  										드래곤플라이
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901035" id="r_20240305901035" onclick="openReportViewer('20240305901035'); return false;" title="매출액또는손익구조30%(대규모법인은15%)이상변동 공시뷰어 새창">매출액또는손익구조30%(대규모법인은15%)이상변동
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="드래곤플라이">드래곤플라이</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:49
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00269852', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="폴라리스오피스 기업개황 새창">
#  										폴라리스오피스
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901107" id="r_20240305901107" onclick="openReportViewer('20240305901107'); return false;" title="타법인주식및출자증권취득결정(종속회사의주요경영사항) 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>타법인주식및출자증권취득결정(종속회사의주요경영사항)
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="폴라리스오피스">폴라리스오피스</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:48
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_etc" style="cursor:default" title="기타법인">기</span>
#  <a href="javascript:openCorpInfoNew('00138613', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="아산저축은행 기업개황 새창">
#  										아산저축은행
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000606" id="r_20240305000606" onclick="openReportViewer('20240305000606'); return false;" title="감사보고서 공시뷰어 새창">감사보고서
#  									 (2023.12)
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="안진회계법인">안진회계법인</td>
#  <td>2024.03.05</td>
#  <td></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:48
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('00404701', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="한국자산신탁 기업개황 새창">
#  										한국자산신탁
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305801063" id="r_20240305801063" onclick="openReportViewer('20240305801063'); return false;" title="주주총회소집결의 공시뷰어 새창">주주총회소집결의
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="한국자산신탁">한국자산신탁</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kospi_other" style="cursor:default" title="본 공시사항은 한국거래소 유가증권시장본부 소관임">유</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:48
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('00356361', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="LG화학 기업개황 새창">
#  										LG화학
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000605" id="r_20240305000605" onclick="openReportViewer('20240305000605'); return false;" title="증권신고서(채무증권) 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 유가증권 발행조건이 확정되어 제출된 것임">[발행조건확정]</span>증권신고서(채무증권)
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="LG화학">LG화학</td>
#  <td>2024.03.05</td>
#  <td></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:48
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('00382199', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="신한지주 기업개황 새창">
#  										신한지주
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305800945" id="r_20240305800945" onclick="openReportViewer('20240305800945'); return false;" title="기업지배구조보고서공시 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 첨부서류가 추가되어 제출된 것임">[첨부추가]</span>기업지배구조보고서공시
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="신한지주">신한지주</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kospi_other" style="cursor:default" title="본 공시사항은 한국거래소 유가증권시장본부 소관임">유</span><span class="tagCom_jung_other" style="cursor:default" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:47
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('01381391', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="에스피소프트 기업개황 새창">
#  										에스피소프트
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901070" id="r_20240305901070" onclick="openReportViewer('20240305901070'); return false;" title="조회공시요구(현저한시황변동) 공시뷰어 새창">조회공시요구(현저한시황변동)
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="코스닥시장본부">코스닥시장본부</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:47
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('00500254', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="GS 기업개황 새창">
#  										GS
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305801085" id="r_20240305801085" onclick="openReportViewer('20240305801085'); return false;" title="매출액또는손익구조30%(대규모법인은15%)이상변경 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>매출액또는손익구조30%(대규모법인은15%)이상변경(자회사의 주요경영사항)
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="GS">GS</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kospi_other" style="cursor:default" title="본 공시사항은 한국거래소 유가증권시장본부 소관임">유</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:47
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00919966', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="신라젠 기업개황 새창">
#  										신라젠
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000604" id="r_20240305000604" onclick="openReportViewer('20240305000604'); return false;" title="의결권대리행사권유참고서류 공시뷰어 새창">의결권대리행사권유참고서류
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="신라젠">신라젠</td>
#  <td>2024.03.05</td>
#  <td></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:47
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('01326792', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="비투엔 기업개황 새창">
#  										비투엔
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901054" id="r_20240305901054" onclick="openReportViewer('20240305901054'); return false;" title="최대주주변경을수반하는주식담보제공계약체결 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>최대주주변경을수반하는주식담보제공계약체결
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="비투엔">비투엔</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span><span class="tagCom_jung_other" style="cursor:default" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:47
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00176835', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="농우바이오 기업개황 새창">
#  										농우바이오
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000602" id="r_20240305000602" onclick="openReportViewer('20240305000602'); return false;" title="주주총회소집공고 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>주주총회소집공고
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="농우바이오">농우바이오</td>
#  <td>2024.03.05</td>
#  <td></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:46
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00815767', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="위메이드플레이 기업개황 새창">
#  										위메이드플레이
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901018" id="r_20240305901018" onclick="openReportViewer('20240305901018'); return false;" title="주주총회집중일개최사유신고 공시뷰어 새창">주주총회집중일개최사유신고
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="위메이드플레이">위메이드플레이</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:46
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00269852', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="폴라리스오피스 기업개황 새창">
#  										폴라리스오피스
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305900979" id="r_20240305900979" onclick="openReportViewer('20240305900979'); return false;" title="타법인주식및출자증권취득결정(자율공시) 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>타법인주식및출자증권취득결정(자율공시)
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="폴라리스오피스">폴라리스오피스</td>
#  <td>2024.03.05</td>
# ...
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="위메이드플레이">위메이드플레이</td>
#  <td>2024.03.05</td>
#  <td></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:39
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('00980122', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="JB금융지주 기업개황 새창">
#  										JB금융지주
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000585" id="r_20240305000585" onclick="openReportViewer('20240305000585'); return false;" title="의결권대리행사권유참고서류 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>의결권대리행사권유참고서류
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="얼라인파트너스자산운용">얼라인파트너스자산운용</td>
#  <td>2024.03.05</td>
#  <td></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:39
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00161462', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="에이티넘인베스트 기업개황 새창">
#  										에이티넘인베스트
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000583" id="r_20240305000583" onclick="openReportViewer('20240305000583'); return false;" title="의결권대리행사권유참고서류 공시뷰어 새창">의결권대리행사권유참고서류
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="에이티넘인베스트">에이티넘인베스트</td>
#  <td>2024.03.05</td>
#  <td></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:38
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_etc" style="cursor:default" title="기타법인">기</span>
#  <a href="javascript:openCorpInfoNew('00207108', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="이랜드월드 기업개황 새창">
#  										이랜드월드
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000582" id="r_20240305000582" onclick="openReportViewer('20240305000582'); return false;" title="증권신고서(채무증권) 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 유가증권 발행조건이 확정되어 제출된 것임">[발행조건확정]</span>증권신고서(채무증권)
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="이랜드월드">이랜드월드</td>
#  <td>2024.03.05</td>
#  <td></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:38
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00663669', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="폴라리스우노 기업개황 새창">
#  										폴라리스우노
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305900978" id="r_20240305900978" onclick="openReportViewer('20240305900978'); return false;" title="타법인주식및출자증권취득결정(자율공시) 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>타법인주식및출자증권취득결정(자율공시)
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="폴라리스우노">폴라리스우노</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:37
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00919966', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="신라젠 기업개황 새창">
#  										신라젠
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901055" id="r_20240305901055" onclick="openReportViewer('20240305901055'); return false;" title="주주총회소집결의 공시뷰어 새창">주주총회소집결의
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="신라젠">신라젠</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:37
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('01796858', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="신영스팩10호 기업개황 새창">
#  										신영스팩10호
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305900987" id="r_20240305900987" onclick="openReportViewer('20240305900987'); return false;" title="감사보고서제출 공시뷰어 새창">감사보고서제출
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="신영스팩10호">신영스팩10호</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:37
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00416414', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="넥스턴바이오 기업개황 새창">
#  										넥스턴바이오
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305900899" id="r_20240305900899" onclick="openReportViewer('20240305900899'); return false;" title="기타경영사항(자율공시)(제1,3,4회차 무기명식 무보증 사모 전환사채 만기전 취득 후 재매각의 건) 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>기타경영사항(자율공시)
#
#  		  							(제1,3,4회차 무기명식 무보증 사모 전환사채 만기전 취득 후 재매각의 건)
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="넥스턴바이오">넥스턴바이오</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span><span class="tagCom_jung_other" style="cursor:default" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:36
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('00244455', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="케이티앤지 기업개황 새창">
#  										케이티앤지
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000580" id="r_20240305000580" onclick="openReportViewer('20240305000580'); return false;" title="의결권대리행사권유참고서류 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>의결권대리행사권유참고서류
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="케이티앤지">케이티앤지</td>
#  <td>2024.03.05</td>
#  <td></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:36
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('01046203', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="스튜디오산타클로스 기업개황 새창">
#  										스튜디오산타클로스
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000574" id="r_20240305000574" onclick="openReportViewer('20240305000574'); return false;" title="주요사항보고서(주권관련사채권양수결정) 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>주요사항보고서(주권관련사채권양수결정)
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="스튜디오산타클로스">스튜디오산타클로스</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_jung_other" style="cursor:default" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:36
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('01046203', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="스튜디오산타클로스 기업개황 새창">
#  										스튜디오산타클로스
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000561" id="r_20240305000561" onclick="openReportViewer('20240305000561'); return false;" title="주요사항보고서(유상증자결정) 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>주요사항보고서(유상증자결정)
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="스튜디오산타클로스">스튜디오산타클로스</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_jung_other" style="cursor:default" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:36
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00307028', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="경남제약 기업개황 새창">
#  										경남제약
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000579" id="r_20240305000579" onclick="openReportViewer('20240305000579'); return false;" title="의결권대리행사권유참고서류 공시뷰어 새창">의결권대리행사권유참고서류
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="경남제약">경남제약</td>
#  <td>2024.03.05</td>
#  <td></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:36
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00409681', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="아스트 기업개황 새창">
#  										아스트
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000533" id="r_20240305000533" onclick="openReportViewer('20240305000533'); return false;" title="주요사항보고서(유상증자결정) 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>주요사항보고서(유상증자결정)
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="아스트">아스트</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_jung_other" style="cursor:default" title="본 보고서 제출 후 정정신고가 있으니 관련 보고서를 참조하시기 바람">정</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:35
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('00244455', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="케이티앤지 기업개황 새창">
#  										케이티앤지
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000578" id="r_20240305000578" onclick="openReportViewer('20240305000578'); return false;" title="의결권대리행사권유참고서류 공시뷰어 새창">의결권대리행사권유참고서류
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="AGNES">AGNES</td>
#  <td>2024.03.05</td>
#  <td></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:35
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('00165680', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="호텔신라 기업개황 새창">
#  										호텔신라
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305800986" id="r_20240305800986" onclick="openReportViewer('20240305800986'); return false;" title="감사보고서제출 공시뷰어 새창">감사보고서제출
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="호텔신라">호텔신라</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kospi_other" style="cursor:default" title="본 공시사항은 한국거래소 유가증권시장본부 소관임">유</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:34
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00815767', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="위메이드플레이 기업개황 새창">
#  										위메이드플레이
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000577" id="r_20240305000577" onclick="openReportViewer('20240305000577'); return false;" title="주주총회소집공고 공시뷰어 새창">주주총회소집공고
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="위메이드플레이">위메이드플레이</td>
#  <td>2024.03.05</td>
#  <td></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:34
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00161462', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="에이티넘인베스트 기업개황 새창">
#  										에이티넘인베스트
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000576" id="r_20240305000576" onclick="openReportViewer('20240305000576'); return false;" title="주주총회소집공고 공시뷰어 새창">주주총회소집공고
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="에이티넘인베스트">에이티넘인베스트</td>
#  <td>2024.03.05</td>
#  <td></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:33
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
#  <a href="javascript:openCorpInfoNew('00560122', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="한울소재과학 기업개황 새창">
#  										한울소재과학
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305901016" id="r_20240305901016" onclick="openReportViewer('20240305901016'); return false;" title="거래처와의거래중단 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>거래처와의거래중단
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="한울소재과학">한울소재과학</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:33
#  							</td>
#  <td class="tL">
#  <span class="innerWrapTag">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('00111722', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="미래에셋증권 기업개황 새창">
#  										미래에셋증권
#  									</a>
#  </span>
#  <a href="http://ci.securities.miraeasset.com" target="new">
#  <span class="tagCom_ir" title="기업 IR페이지 연결">IR</span>
#  </a>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000573" id="r_20240305000573" onclick="openReportViewer('20240305000573'); return false;" title="투자설명서(일괄신고) 공시뷰어 새창">투자설명서(일괄신고)
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="미래에셋증권">미래에셋증권</td>
#  <td>2024.03.05</td>
#  <td></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:32
#  							</td>
#  <td class="tL">
#  <span class="innerWrap">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('00113526', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="대한항공 기업개황 새창">
#  										대한항공
#  									</a>
#  </span>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305800959" id="r_20240305800959" onclick="openReportViewer('20240305800959'); return false;" title="감사보고서제출 공시뷰어 새창">감사보고서제출
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="대한항공">대한항공</td>
#  <td>2024.03.05</td>
#  <td><span class="tagCom_kospi_other" style="cursor:default" title="본 공시사항은 한국거래소 유가증권시장본부 소관임">유</span></td>
#  </tr>,
#  <tr>
#  <td>
#
#
#
#  								17:31
#  							</td>
#  <td class="tL">
#  <span class="innerWrapTag">
#  <span class="tagCom_kospi" style="cursor:default" title="유가증권시장">유</span>
#  <a href="javascript:openCorpInfoNew('00111722', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="미래에셋증권 기업개황 새창">
#  										미래에셋증권
#  									</a>
#  </span>
#  <a href="http://ci.securities.miraeasset.com" target="new">
#  <span class="tagCom_ir" title="기업 IR페이지 연결">IR</span>
#  </a>
#  </td>
#  <td class="tL">
#  <a href="/dsaf001/main.do?rcpNo=20240305000569" id="r_20240305000569" onclick="openReportViewer('20240305000569'); return false;" title="일괄신고추가서류(파생결합증권-주가연계증권) 공시뷰어 새창">일괄신고추가서류(파생결합증권-주가연계증권)
#
#
#  								</a>
#  </td>
#  <td class="tL ellipsis" title="미래에셋증권">미래에셋증권</td>
#  <td>2024.03.05</td>
#  <td></td>
#  </tr>]

# %%
# -> 정확하게 공시 정보들에 대해서 접근을 하기 위해서
#     tbody 속에 있는 tr로 접근하는 게 아니라 좀 더 나아보임!
# -> 모든 tr 나오세요가 아니라 thead에 tr 나오니..
# -> tbody 속에 있는 tr만 다 나오세요! -> 공시들만


soup.find("tbody").find_all("tr")[0]
# Out:
# <tr>
# <td>
#
#
#
# 								19:29
# 							</td>
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('01375822', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="에이프릴바이오 기업개황 새창">
# 										에이프릴바이오
# 									</a>
# </span>
# </td>
# <td class="tL">
# <a href="/dsaf001/main.do?rcpNo=20240305901186" id="r_20240305901186" onclick="openReportViewer('20240305901186'); return false;" title="매출액또는손익구조30%(대규모법인은15%)이상변동 공시뷰어 새창"><span class="txtCB" title="본 보고서명으로 이미 제출된 보고서의 기재내용이 변경되어 제출된 것임">[기재정정]</span>매출액또는손익구조30%(대규모법인은15%)이상변동
#
#
# 								</a>
# </td>
# <td class="tL ellipsis" title="에이프릴바이오">에이프릴바이오</td>
# <td>2024.03.05</td>
# <td><span class="tagCom_kosdaq_other" style="cursor:default" title="본 공시사항은 한국거래소 코스닥시장본부 소관임">코</span></td>
# </tr>

# %%
idx = 0
temp = soup.find("tbody").find_all("tr")[idx]
temp

# 1) 1번 공시의 제출 시간 
# -> 안 좋은 공시 : 주말, 금요일 장 끝나고...

temp.find_all("td")[0].text # 원하는 정보는 있지만 공백 문자들이 존재 strip(): 양쪽 or 정규식
temp.find_all("td")[0].text.strip() # 양쪽에 공백만 날려줌 -> 정규식으로 공백처리를 해야함.
# re.sub(r"\r|\n|\t\s","",str(temp))
# Out:
# '19:29'

# %%
# Q) 1번 공시를 제출한 회사가 속한 시장을 보자

temp.find_all("td")[1].find_all("span")[1].get("title")
# Out:
# '코스닥시장'

# %%
# Q) 1번 공시 대상인 회사의 이름을 출력!
temp.find_all("td")[1].text.strip()
#--> 처리할 수는 있는데 정확히 타겟팅은 안 됨
# Out:
# '코\n\r\n\t\t\t\t\t\t\t\t\t\t에이프릴바이오'

# %%
temp.find_all("td")[1].find("a").text.strip()
# Out:
# '에이프릴바이오'

# %%
temp.find_all("td")[1]
# Out:
# <td class="tL">
# <span class="innerWrap">
# <span class="tagCom_kosdaq" style="cursor:default" title="코스닥시장">코</span>
# <a href="javascript:openCorpInfoNew('01375822', 'winCorpInfo', '/dsae001/selectPopup.ax');" title="에이프릴바이오 기업개황 새창">
# 										에이프릴바이오
# 									</a>
# </span>
# </td>

# %%
# Q) 1번 공시의 회사의 코드값을 출력해보세요.
temp.find_all("td")[1].find("a").get("href")
# Out:
# "javascript:openCorpInfoNew('01375822', 'winCorpInfo', '/dsae001/selectPopup.ax');"

# %%
re.findall(r"\d{8}",temp.find_all("td")[1].find("a").get("href"))
# Out:
# ['01375822']

# %%
# Q) 1번 공시의 고유값 rcpNo 
re.findall(r"\d{14}",temp.find_all("td")[2].find("a").get("href"))

# Q) 1번 공시의 공시 이름 출력
# Out:
# ['20240305901186']

# %%
temp.find_all("td")[2].find("a").text.strip()
# Out:
# '[기재정정]매출액또는손익구조30%(대규모법인은15%)이상변동'

# %%
# Q) 1번 공시에 대한 요청 일자
temp.find_all("td")[4].text
# Out:
# '2024.03.06'

# %%
# Q1) for문을 이용해서 지금 페이지의 공시 정보를 출력
# -> 제출 시간, 회사가 속한 시장(fullname), 회사이름, 회사 코드, 공시이름, 공시의 고유값, 요청일자
cnt= len(soup.find("tbody").find_all("tr"))
         
for idx in range(cnt):
    temp = soup.find("tbody").find_all("tr")[idx]
    sub_time = temp.find_all("td")[0].text.strip()
    market = temp.find_all("td")[1].find_all("span")[1].get("title")
    cName = temp.find_all("td")[3].text
    code = re.findall(r"\d{8}",temp.find_all("td")[1].find("a").get("href"))[0]
    tName= re.sub(r"\t|\n","",temp.find_all("td")[2].text.strip())
    rcpNo= re.findall(r"\d{14}",temp.find_all("td")[2].find("a").get("href"))[0]
    ord_date = temp.find_all("td")[4].text
    print("제출시간", sub_time)
    print("시장", market)
    print("회사이름", cName)
    print("회사 코드", code)
    print("공시이름", tName)
    print("고유값", rcpNo)
    print("요청일자", ord_date)
    print("#"*40)
# Out:
# 제출시간 19:29
# 시장 코스닥시장
# 회사이름 에이프릴바이오
# 회사 코드 01375822
# 공시이름 [기재정정]매출액또는손익구조30%(대규모법인은15%)이상변동
# 고유값 20240305901186
# 요청일자 2024.03.05
# ########################################
# 제출시간 18:58
# 시장 코스닥시장
# 회사이름 씨씨에스
# 회사 코드 00249441
# 공시이름 주요사항보고서(소송등의제기)
# 고유값 20240305000637
# 요청일자 2024.03.06
# ########################################
# 제출시간 18:50
# 시장 코스닥시장
# 회사이름 에스앤디
# 회사 코드 00560849
# 공시이름 주주총회집중일개최사유신고
# 고유값 20240305901177
# 요청일자 2024.03.05
# ########################################
# 제출시간 18:48
# 시장 코스닥시장
# 회사이름 씨유메디칼
# 회사 코드 00681249
# 공시이름 주주총회소집결의
# 고유값 20240305901172
# 요청일자 2024.03.05
# ########################################
# 제출시간 18:43
# 시장 유가증권시장
# 회사이름 남양유업
# 회사 코드 00107598
# 공시이름 소송등의제기ㆍ신청(경영권분쟁소송)
# 고유값 20240305801171
# 요청일자 2024.03.05
# ########################################
# 제출시간 18:43
# 시장 코스닥시장
# 회사이름 씨씨에스
# 회사 코드 00249441
#   (이사회결의 효력정지 및 대표이사직무집행정지 가처분)
# 고유값 20240305901175
# 요청일자 2024.03.05
# ########################################
# 제출시간 18:42
# 시장 유가증권시장
# 회사이름 카프로
# 회사 코드 00159810
# 공시이름 주주총회소집결의
# 고유값 20240305801174
# 요청일자 2024.03.05
# ########################################
# 제출시간 18:41
# 시장 유가증권시장
# 회사이름 카프로
# 회사 코드 00159810
# 공시이름 주요사항보고서(감자결정)
# 고유값 20240305000629
# 요청일자 2024.03.06
# ########################################
# 제출시간 18:36
# 시장 코스닥시장
# 회사이름 큐로홀딩스
# 회사 코드 00296324
# 공시이름 [기재정정]최대주주변경을수반하는주식담보제공계약체결
# 고유값 20240305901165
# 요청일자 2024.03.05
# ########################################
# 제출시간 18:30
# 시장 코스닥시장
# 회사이름 에이티세미콘
# 회사 코드 00458562
# 공시이름 주권관련사채권의취득결정
# 고유값 20240305901162
# 요청일자 2024.03.05
# ########################################
# 제출시간 18:29
# 시장 코스닥시장
# 회사이름 에이티세미콘
# 회사 코드 00458562
#   (주식회사 에이티세미콘 제16회차 무기명식 이권부 무보증 사모 전환사채 취득 후 재매각의 건)
# 고유값 20240305901161
# 요청일자 2024.03.05
# ########################################
# 제출시간 18:23
# 시장 코스닥시장
# 회사이름 지더블유바이텍
# 회사 코드 00257149
# 공시이름 [기재정정]최대주주변경
# 고유값 20240305901159
# 요청일자 2024.03.05
# ########################################
# 제출시간 18:21
# 시장 코스닥시장
# 회사이름 에이티세미콘
# 회사 코드 00458562
#   (제12회차, 제14회차, 제16회차 무기명식 이권부 무보증 사모 전환사채 취득 후 재매각의 건)
# 고유값 20240305901160
# 요청일자 2024.03.05
# ########################################
# 제출시간 18:21
# 시장 코스닥시장
# 회사이름 에스앤디
# 회사 코드 00560849
# 공시이름 주주총회소집결의
# 고유값 20240305901164
# 요청일자 2024.03.05
# ########################################
# 제출시간 18:14
# 시장 코스닥시장
# 회사이름 EDGC
# 회사 코드 01182550
# 공시이름 주주총회소집결의
# 고유값 20240305901157
# 요청일자 2024.03.05
# ########################################
# 제출시간 18:11
# 시장 코스닥시장
# 회사이름 큐캐피탈
# 회사 코드 00267942
# 공시이름 [기재정정]최대주주변경을수반하는주식담보제공계약체결
# 고유값 20240305901098
# 요청일자 2024.03.05
# ########################################
# 제출시간 18:10
# 시장 코스닥시장
# 회사이름 신영스팩9호
# 회사 코드 01689938
# 공시이름 감사보고서제출
# 고유값 20240305901124
# 요청일자 2024.03.05
# ########################################
# 제출시간 18:09
# 시장 코스닥시장
# 회사이름 엑스큐어
# 회사 코드 00683007
# 공시이름 주주총회소집결의
# 고유값 20240305901091
# 요청일자 2024.03.05
# ########################################
# 제출시간 18:09
# 시장 코스닥시장
# 회사이름 신라젠
# 회사 코드 00919966
# 공시이름 주주총회집중일개최사유신고
# 고유값 20240305901089
# 요청일자 2024.03.05
# ########################################
# 제출시간 18:09
# 시장 코스닥시장
# 회사이름 디딤이앤에프
# 회사 코드 01068658
# 공시이름 [기재정정]주주명부폐쇄기간또는기준일설정
# 고유값 20240305901069
# 요청일자 2024.03.05
# ########################################
# 제출시간 18:08
# 시장 코스닥시장
# 회사이름 디딤이앤에프
# 회사 코드 01068658
#   (임시주주총회)]주주총회소집결의
# 고유값 20240305901064
# 요청일자 2024.03.05
# ########################################
# 제출시간 18:03
# 시장 코스닥시장
# 회사이름 한솔인티큐브
# 회사 코드 00470829
# 공시이름 주주총회소집결의
# 고유값 20240305901058
# 요청일자 2024.03.05
# ########################################
# 제출시간 18:03
# 시장 유가증권시장
# 회사이름 OCI홀딩스
# 회사 코드 00148896
# 공시이름 감사보고서제출(자회사의 주요경영사항)
# 고유값 20240305801129
# 요청일자 2024.03.05
# ########################################
# 제출시간 18:01
# 시장 코스닥시장
# 회사이름 신영스팩8호
# 회사 코드 01656374
# 공시이름 감사보고서제출
# 고유값 20240305901116
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:59
# 시장 유가증권시장
# 회사이름 롯데칠성음료
# 회사 코드 00120571
# 공시이름 의결권대리행사권유참고서류
# 고유값 20240305000621
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:59
# 시장 유가증권시장
# 회사이름 한국자산신탁
# 회사 코드 00404701
# 공시이름 주주총회소집공고
# 고유값 20240305000620
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:59
# 시장 코스닥시장
# 회사이름 클리노믹스
# 회사 코드 01201970
# 공시이름 [기재정정]주요사항보고서(유상증자결정)
# 고유값 20240305000608
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:59
# 시장 코스닥시장
# 회사이름 신영스팩7호
# 회사 코드 01612608
# 공시이름 감사보고서제출
# 고유값 20240305901111
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:58
# 시장 유가증권시장
# 회사이름 OCI
# 회사 코드 01760738
# 공시이름 감사보고서제출
# 고유값 20240305801114
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:58
# 시장 코스닥시장
# 회사이름 지니뮤직
# 회사 코드 00223762
# 공시이름 감사보고서제출
# 고유값 20240305901095
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:58
# 시장 유가증권시장
# 회사이름 DL이앤씨
# 회사 코드 01524093
# 공시이름 최대주주등소유주식변동신고서
# 고유값 20240305801127
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:58
# 시장 유가증권시장
# 회사이름 LG
# 회사 코드 00120021
# 공시이름 감사보고서제출(자회사의 주요경영사항)
# 고유값 20240305801113
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:55
# 시장 유가증권시장
# 회사이름 디아이동일
# 회사 코드 00118345
# 공시이름 소송등의제기ㆍ신청(경영권분쟁소송)
# 고유값 20240305801122
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:55
# 시장 유가증권시장
# 회사이름 롯데칠성음료
# 회사 코드 00120571
# 공시이름 주주총회소집공고
# 고유값 20240305000615
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:54
# 시장 코스닥시장
# 회사이름 티에스넥스젠
# 회사 코드 00317487
# 공시이름 주요사항보고서(자기전환사채매도결정)
# 고유값 20240305000614
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:54
# 시장 코스닥시장
# 회사이름 올리패스
# 회사 코드 01070149
# 공시이름 [기재정정]주요사항보고서(유상증자결정)
# 고유값 20240305000597
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:54
# 시장 유가증권시장
# 회사이름 롯데칠성음료
# 회사 코드 00120571
# 공시이름 주주총회소집결의
# 고유값 20240305801106
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:53
# 시장 유가증권시장
# 회사이름 대상홀딩스
# 회사 코드 00539274
# 공시이름 [기재정정]주주총회소집결의
# 고유값 20240305801013
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:53
# 시장 코넥스시장
# 회사이름 럭스피아
# 회사 코드 00578325
# 공시이름 주주총회소집공고
# 고유값 20240305000610
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:52
# 시장 기타법인
# 회사이름 스노우
# 회사 코드 01213832
# 공시이름 비유동자산처분결정
# 고유값 20240305000609
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:52
# 시장 코스닥시장
# 회사이름 드래곤플라이
# 회사 코드 00230036
# 공시이름 주주총회집중일개최사유신고
# 고유값 20240305901048
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:52
# 시장 코스닥시장
# 회사이름 드래곤플라이
# 회사 코드 00230036
# 공시이름 주주총회소집결의
# 고유값 20240305901042
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:51
# 시장 유가증권시장
# 회사이름 LG유플러스
# 회사 코드 00231363
# 공시이름 감사보고서제출
# 고유값 20240305801033
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:51
# 시장 유가증권시장
# 회사이름 효성첨단소재
# 회사 코드 01316254
# 공시이름 풍문또는보도에대한해명(미확정)
# 고유값 20240305801105
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:50
# 시장 코스닥시장
# 회사이름 김인수
# 회사 코드 00367695
# 공시이름 의결권대리행사권유참고서류
# 고유값 20240305000607
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:50
# 시장 코스닥시장
# 회사이름 드래곤플라이
# 회사 코드 00230036
# 공시이름 매출액또는손익구조30%(대규모법인은15%)이상변동
# 고유값 20240305901035
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:49
# 시장 코스닥시장
# 회사이름 폴라리스오피스
# 회사 코드 00269852
# 공시이름 [기재정정]타법인주식및출자증권취득결정(종속회사의주요경영사항)
# 고유값 20240305901107
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:48
# 시장 기타법인
# 회사이름 안진회계법인
# 회사 코드 00138613
#  (2023.12)
# 고유값 20240305000606
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:48
# 시장 유가증권시장
# 회사이름 한국자산신탁
# 회사 코드 00404701
# 공시이름 주주총회소집결의
# 고유값 20240305801063
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:48
# 시장 유가증권시장
# 회사이름 LG화학
# 회사 코드 00356361
# 공시이름 [발행조건확정]증권신고서(채무증권)
# 고유값 20240305000605
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:48
# 시장 유가증권시장
# 회사이름 신한지주
# 회사 코드 00382199
# 공시이름 [첨부추가]기업지배구조보고서공시
# 고유값 20240305800945
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:47
# 시장 코스닥시장
# 회사이름 코스닥시장본부
# 회사 코드 01381391
# 공시이름 조회공시요구(현저한시황변동)
# 고유값 20240305901070
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:47
# 시장 유가증권시장
# 회사이름 GS
# 회사 코드 00500254
# 공시이름 [기재정정]매출액또는손익구조30%(대규모법인은15%)이상변경(자회사의 주요경영사항)
# 고유값 20240305801085
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:47
# 시장 코스닥시장
# 회사이름 신라젠
# 회사 코드 00919966
# 공시이름 의결권대리행사권유참고서류
# 고유값 20240305000604
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:47
# 시장 코스닥시장
# 회사이름 비투엔
# 회사 코드 01326792
# 공시이름 [기재정정]최대주주변경을수반하는주식담보제공계약체결
# 고유값 20240305901054
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:47
# 시장 코스닥시장
# 회사이름 농우바이오
# 회사 코드 00176835
# 공시이름 [기재정정]주주총회소집공고
# 고유값 20240305000602
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:46
# 시장 코스닥시장
# 회사이름 위메이드플레이
# 회사 코드 00815767
# 공시이름 주주총회집중일개최사유신고
# 고유값 20240305901018
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:46
# 시장 코스닥시장
# 회사이름 폴라리스오피스
# 회사 코드 00269852
# 공시이름 [기재정정]타법인주식및출자증권취득결정(자율공시)
# 고유값 20240305900979
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:46
# 시장 유가증권시장
# 회사이름 아시아나항공
# 회사 코드 00138792
# 공시이름 신규시설투자등
# 고유값 20240305801075
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:46
# 시장 유가증권시장
# 회사이름 한전산업
# 회사 코드 00194947
# 공시이름 소송등의제기ㆍ신청(일정금액이상의청구)
# 고유값 20240305801053
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:45
# 시장 코스닥시장
# 회사이름 드래곤플라이
# 회사 코드 00230036
# 공시이름 의결권대리행사권유참고서류
# 고유값 20240305000600
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:45
# 시장 코스닥시장
# 회사이름 보성파워텍
# 회사 코드 00267881
# 공시이름 의결권대리행사권유참고서류
# 고유값 20240305000599
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:43
# 시장 기타법인
# 회사이름 현대커머셜
# 회사 코드 00603278
# 공시이름 주요사항보고서(자본으로인정되는채무증권발행결정)
# 고유값 20240305000596
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:42
# 시장 유가증권시장
# 회사이름 한진칼
# 회사 코드 00983040
# 공시이름 감사보고서제출(자회사의 주요경영사항)
# 고유값 20240305801043
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:42
# 시장 유가증권시장
# 회사이름 GS리테일
# 회사 코드 00140177
# 공시이름 주주총회소집결의
# 고유값 20240305801031
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:42
# 시장 코스닥시장
# 회사이름 위메이드플레이
# 회사 코드 00815767
# 공시이름 [기재정정]주식매수선택권부여에관한신고
# 고유값 20240305000594
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:42
# 시장 유가증권시장
# 회사이름 서흥
# 회사 코드 00131692
# 공시이름 주주총회집중일개최사유신고
# 고유값 20240305801045
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:42
# 시장 유가증권시장
# 회사이름 GS리테일
# 회사 코드 00140177
# 공시이름 [기재정정]매출액또는손익구조30%(대규모법인은15%)이상변경
# 고유값 20240305801038
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:42
# 시장 유가증권시장
# 회사이름 신영증권
# 회사 코드 00136721
# 공시이름 투자설명서(일괄신고)
# 고유값 20240305000593
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:41
# 시장 코스닥시장
# 회사이름 플레이디
# 회사 코드 00862853
# 공시이름 감사보고서제출
# 고유값 20240305901023
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:41
# 시장 코스닥시장
# 회사이름 폴라리스세원
# 회사 코드 00617998
# 공시이름 [기재정정]타법인주식및출자증권취득결정(종속회사의주요경영사항)
# 고유값 20240305901082
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:41
# 시장 코스닥시장
# 회사이름 와이엔텍
# 회사 코드 00190756
# 공시이름 현금ㆍ현물배당결정
# 고유값 20240305901024
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:41
# 시장 코스닥시장
# 회사이름 와이엔텍
# 회사 코드 00190756
# 공시이름 주주총회소집결의
# 고유값 20240305901034
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:40
# 시장 유가증권시장
# 회사이름 신영증권
# 회사 코드 00136721
# 공시이름 일괄신고추가서류(파생결합증권-주가연계증권)
# 고유값 20240305000590
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:40
# 시장 코스닥시장
# 회사이름 드래곤플라이
# 회사 코드 00230036
# 공시이름 주주총회소집공고
# 고유값 20240305000589
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:40
# 시장 코스닥시장
# 회사이름 이랜텍
# 회사 코드 00206659
# 공시이름 현금ㆍ현물배당결정
# 고유값 20240305901011
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:40
# 시장 유가증권시장
# 회사이름 금호건설
# 회사 코드 00106313
# 공시이름 의결권대리행사권유참고서류
# 고유값 20240305000588
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:40
# 시장 코스닥시장
# 회사이름 신라젠
# 회사 코드 00919966
# 공시이름 주주총회소집공고
# 고유값 20240305000587
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:40
# 시장 코스닥시장
# 회사이름 이랜텍
# 회사 코드 00206659
# 공시이름 주주총회소집결의
# 고유값 20240305901009
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:39
# 시장 코스닥시장
# 회사이름 위메이드플레이
# 회사 코드 00815767
# 공시이름 [기재정정]주식매수선택권부여에관한신고
# 고유값 20240305000586
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:39
# 시장 유가증권시장
# 회사이름 얼라인파트너스자산운용
# 회사 코드 00980122
# 공시이름 [기재정정]의결권대리행사권유참고서류
# 고유값 20240305000585
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:39
# 시장 코스닥시장
# 회사이름 에이티넘인베스트
# 회사 코드 00161462
# 공시이름 의결권대리행사권유참고서류
# 고유값 20240305000583
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:38
# 시장 기타법인
# 회사이름 이랜드월드
# 회사 코드 00207108
# 공시이름 [발행조건확정]증권신고서(채무증권)
# 고유값 20240305000582
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:38
# 시장 코스닥시장
# 회사이름 폴라리스우노
# 회사 코드 00663669
# 공시이름 [기재정정]타법인주식및출자증권취득결정(자율공시)
# 고유값 20240305900978
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:37
# 시장 코스닥시장
# 회사이름 신라젠
# 회사 코드 00919966
# 공시이름 주주총회소집결의
# 고유값 20240305901055
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:37
# 시장 코스닥시장
# 회사이름 신영스팩10호
# 회사 코드 01796858
# 공시이름 감사보고서제출
# 고유값 20240305900987
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:37
# 시장 코스닥시장
# 회사이름 넥스턴바이오
# 회사 코드 00416414
#   (제1,3,4회차 무기명식 무보증 사모 전환사채 만기전 취득 후 재매각의 건)
# 고유값 20240305900899
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:36
# 시장 유가증권시장
# 회사이름 케이티앤지
# 회사 코드 00244455
# 공시이름 [기재정정]의결권대리행사권유참고서류
# 고유값 20240305000580
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:36
# 시장 코스닥시장
# 회사이름 스튜디오산타클로스
# 회사 코드 01046203
# 공시이름 [기재정정]주요사항보고서(주권관련사채권양수결정)
# 고유값 20240305000574
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:36
# 시장 코스닥시장
# 회사이름 스튜디오산타클로스
# 회사 코드 01046203
# 공시이름 [기재정정]주요사항보고서(유상증자결정)
# 고유값 20240305000561
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:36
# 시장 코스닥시장
# 회사이름 경남제약
# 회사 코드 00307028
# 공시이름 의결권대리행사권유참고서류
# 고유값 20240305000579
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:36
# 시장 코스닥시장
# 회사이름 아스트
# 회사 코드 00409681
# 공시이름 [기재정정]주요사항보고서(유상증자결정)
# 고유값 20240305000533
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:35
# 시장 유가증권시장
# 회사이름 AGNES
# 회사 코드 00244455
# 공시이름 의결권대리행사권유참고서류
# 고유값 20240305000578
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:35
# 시장 유가증권시장
# 회사이름 호텔신라
# 회사 코드 00165680
# 공시이름 감사보고서제출
# 고유값 20240305800986
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:34
# 시장 코스닥시장
# 회사이름 위메이드플레이
# 회사 코드 00815767
# 공시이름 주주총회소집공고
# 고유값 20240305000577
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:34
# 시장 코스닥시장
# 회사이름 에이티넘인베스트
# 회사 코드 00161462
# 공시이름 주주총회소집공고
# 고유값 20240305000576
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:33
# 시장 코스닥시장
# 회사이름 한울소재과학
# 회사 코드 00560122
# 공시이름 [기재정정]거래처와의거래중단
# 고유값 20240305901016
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:33
# 시장 유가증권시장
# 회사이름 미래에셋증권
# 회사 코드 00111722
# 공시이름 투자설명서(일괄신고)
# 고유값 20240305000573
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:32
# 시장 유가증권시장
# 회사이름 대한항공
# 회사 코드 00113526
# 공시이름 감사보고서제출
# 고유값 20240305800959
# 요청일자 2024.03.05
# ########################################
# 제출시간 17:31
# 시장 유가증권시장
# 회사이름 미래에셋증권
# 회사 코드 00111722
# 공시이름 일괄신고추가서류(파생결합증권-주가연계증권)
# 고유값 20240305000569
# 요청일자 2024.03.05
# ########################################

# %%
# Q2) 1번에서 출력한 내용을 df에 저장해보세요. 컬럼 이름은 스스로 정해보기

lst= []
cnt= len(soup.find("tbody").find_all("tr"))
         
for idx in range(cnt):
    temp = soup.find("tbody").find_all("tr")[idx]
    sub_time = temp.find_all("td")[0].text.strip()
    market = temp.find_all("td")[1].find_all("span")[1].get("title")
    cName = temp.find_all("td")[3].text
    code = re.findall(r"\d{8}",temp.find_all("td")[1].find("a").get("href"))[0]
    tName= re.sub(r"\t|\n","",temp.find_all("td")[2].text.strip())
    rcpNo= re.findall(r"\d{14}",temp.find_all("td")[2].find("a").get("href"))[0]
    ord_date = temp.find_all("td")[4].text

    lst.append([sub_time, market, cName, code, tName, rcpNo, ord_date])

df = pd.DataFrame(data= lst,
                columns = ["sub_time","market","cName","code","tName", "rcpNo","ord_date"]
                 )

# %%
df.head(4)
# Out:
#   sub_time market    cName      code                              tName  \
# 0    19:29  코스닥시장  에이프릴바이오  01375822  [기재정정]매출액또는손익구조30%(대규모법인은15%)이상변동
# 1    18:58  코스닥시장     씨씨에스  00249441                    주요사항보고서(소송등의제기)
# 2    18:50  코스닥시장     에스앤디  00560849                      주주총회집중일개최사유신고
# 3    18:48  코스닥시장    씨유메디칼  00681249                           주주총회소집결의
#
#             rcpNo    ord_date
# 0  20240305901186  2024.03.05
# 1  20240305000637  2024.03.06
# 2  20240305901177  2024.03.05
# 3  20240305901172  2024.03.05

# %%
# Q3) 2024년 3월 5일의 7페이지를 다 돌아서 
# 698의 공시 정보에 대한 내용에 대한 추출한 정보들을 1개의 df에 담아보세요.
date= "2024.03.05"

for pages in range(1,8):
    url = f"https://dart.fss.or.kr/dsac001/mainAll.do?selectDate={date}&sort=&series=&mdayCnt=0&currentPage={pages}"
    res = requests.get(url)
    soup = BeautifulSoup(res.text, "html.parser")

    lst= []
    cnt= len(soup.find("tbody").find_all("tr"))
             
    for idx in range(cnt):
        temp = soup.find("tbody").find_all("tr")[idx]
        sub_time = temp.find_all("td")[0].text.strip()
        market = temp.find_all("td")[1].find_all("span")[1].get("title")
        cName = temp.find_all("td")[3].text
        code = re.findall(r"\d{8}",temp.find_all("td")[1].find("a").get("href"))[0]
        tName= re.sub(r"\t|\n","",temp.find_all("td")[2].text.strip())
        rcpNo= re.findall(r"\d{14}",temp.find_all("td")[2].find("a").get("href"))[0]
        ord_date = temp.find_all("td")[4].text
    
        lst.append([sub_time, market, cName, code, tName, rcpNo, ord_date])

    if pages ==1:
        df = pd.DataFrame(data= lst,
                        columns = ["sub_time","market","cName","code","tName", "rcpNo","ord_date"]
                         )
    else:
        df1 = pd.DataFrame(data= lst,
                        columns = ["sub_time","market","cName","code","tName", "rcpNo","ord_date"]
                         )
        df = pd.concat([df,df1])

# %%
df
# Out:
#    sub_time  market     cName      code                              tName  \
# 0     19:29   코스닥시장   에이프릴바이오  01375822  [기재정정]매출액또는손익구조30%(대규모법인은15%)이상변동
# 1     18:58   코스닥시장      씨씨에스  00249441                    주요사항보고서(소송등의제기)
# 2     18:50   코스닥시장      에스앤디  00560849                      주주총회집중일개최사유신고
# 3     18:48   코스닥시장     씨유메디칼  00681249                           주주총회소집결의
# 4     18:43  유가증권시장      남양유업  00107598                 소송등의제기ㆍ신청(경영권분쟁소송)
# ..      ...     ...       ...       ...                                ...
# 93    07:30    기타법인  식품안전상생재단  01604423               공시대상기업집단의특수관계인으로부터수증
# 94    07:30   코스닥시장       아스트  00409681                 주요사항보고서(전환사채권발행결정)
# 95    07:30   코스닥시장       엘컴텍  00242712                      의결권대리행사권유참고서류
# 96    07:30    기타법인    우란문화재단  01678589               공시대상기업집단의특수관계인으로부터수증
# 97    07:30  유가증권시장     화인베스틸  00661847                     소액공모공시서류(지분증권)
#
#              rcpNo    ord_date
# 0   20240305901186  2024.03.05
# 1   20240305000637  2024.03.06
# 2   20240305901177  2024.03.05
# 3   20240305901172  2024.03.05
# 4   20240305801171  2024.03.05
# ..             ...         ...
# 93  20240304000588  2024.03.05
# 94  20240304000592  2024.03.05
# 95  20240304000585  2024.03.05
# 96  20240304000573  2024.03.05
# 97  20240304000575  2024.03.05
#
# [698 rows x 7 columns]

# %%
# Q4) 이것을 함수로 만들어보기
# 입력 : 조회일자, 종료일자
# 출력 : 입력 기간 동안의 모든 공시 처리
# df, csv, escel etc

def report(findDT, endDT):
    findDT = datetime.strptime(findDT,"%Y.%m.%d")
    endDT = datetime.strptime(endDT,"%Y.%m.%d")
    
    for date in range(findDT, endDT): # 날짜별
        for pages in range(1,8):     # 그 날자의 페이별로...
                
            url = f"https://dart.fss.or.kr/dsac001/mainAll.do?selectDate={date}&sort=&series=&mdayCnt=0&currentPage={pages}"
            res = requests.get(url)
            soup = BeautifulSoup(res.text, "html.parser")
        
            lst= []
            cnt= len(soup.find("tbody").find_all("tr"))
                     
            for idx in range(cnt): # 그 페이지에 공시벼로...
                temp = soup.find("tbody").find_all("tr")[idx]
                sub_time = temp.find_all("td")[0].text.strip()
                market = temp.find_all("td")[1].find_all("span")[1].get("title")
                cName = temp.find_all("td")[3].text
                code = re.findall(r"\d{8}",temp.find_all("td")[1].find("a").get("href"))[0]
                tName= re.sub(r"\t|\n","",temp.find_all("td")[2].text.strip())
                rcpNo= re.findall(r"\d{14}",temp.find_all("td")[2].find("a").get("href"))[0]
                ord_date = temp.find_all("td")[4].text
            
                lst.append([sub_time, market, cName, code, tName, rcpNo, ord_date])
        
            if pages ==1:
                df = pd.DataFrame(data= lst,
                                columns = ["sub_time","market","cName","code","tName", "rcpNo","ord_date"]
                                 )
            else:
                df1 = pd.DataFrame(data= lst,
                                columns = ["sub_time","market","cName","code","tName", "rcpNo","ord_date"]
                                 )
                df = pd.concat([df,df1])

    return df

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[236], line 1
# ----> 1 report("2024.03.05", "2024.03.06")
#
# Cell In[235], line 9, in report(findDT, endDT)
#       7 findDT = datetime.strptime(findDT,"%Y.%m.%d")
#       8 endDT = datetime.strptime(endDT,"%Y.%m.%d")
# ----> 9 for date in range(findDT, endDT):
#      10     for pages in range(1,8):
#      12         url = f"https://dart.fss.or.kr/dsac001/mainAll.do?selectDate={date}&sort=&series=&mdayCnt=0&currentPage={pages}"
#
# TypeError: 'datetime.datetime' object cannot be interpreted as an integer

# %%
datetime.strptime("2024.03.05","%Y.%m.%d")
# Out:
# datetime.datetime(2024, 3, 5, 0, 0)

# %%
datetime.strptime("2024.03.09","%Y.%m.%d")
# Out:
# datetime.datetime(2024, 3, 9, 0, 0)

# %%
from datetime import date, timedelta

# %%
in_days = "2024.03.05"
out_days ="2024.03.09"

# %%
in_days_dt = datetime.strptime(in_days,"%Y.%m.%d")
out_days_dt = datetime.strptime(out_days,"%Y.%m.%d")
delta = timedelta(days=1)

# %%
diff_days = out_days_dt - in_days_dt + delta# 끝날도 초함해야 해서...
diff_days
# Out:
# datetime.timedelta(days=5)

# %%
days_list = [ ( in_days_dt +delta*(i)).strftime("%Y.%m.%d")  for i in range(diff_days.days)  ]
days_list
# Out:
# ['2024.03.05', '2024.03.06', '2024.03.07', '2024.03.08', '2024.03.09']

# %%
for day in days_list:
    print(day)
# Out:
# 2024.03.05
# 2024.03.06
# 2024.03.07
# 2024.03.08
# 2024.03.09

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[258], line 1
# ----> 1 for i in diff_days:
#       2     print(i)
#
# TypeError: 'datetime.timedelta' object is not iterable

# %%
delta = timedelta(days=1)

# %%
datetime.strptime("2024.03.05","%Y.%m.%d") + delta
# Out:
# datetime.datetime(2024, 3, 6, 0, 0)

# %%
datetime.strptime("2024.03.09","%Y.%m.%d") - datetime.strptime("2024.03.05","%Y.%m.%d")
# Out:
# datetime.timedelta(days=4)

# %%
diff_days = datetime.strptime("2024.03.09","%Y.%m.%d") - datetime.strptime("2024.03.05","%Y.%m.%d")

# %%
a = datetime.strptime("2024.03.05","%Y.%m.%d") + timedelta(days=1)
a.strftime("%Y.%m.%d")
# Out:
# '2024.03.06'

# %%
for i in range(datetime.strptime("2024.03.05","%Y.%m.%d"), datetime.strptime("2024.03.09","%Y.%m.%d")):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[243], line 1
# ----> 1 for i in range(datetime.strptime("2024.03.05","%Y.%m.%d"), datetime.strptime("2024.03.09","%Y.%m.%d")):
#       2     print(i)
#
# TypeError: 'datetime.datetime' object cannot be interpreted as an integer
